# %% [markdown]
# <a href="https://colab.research.google.com/github/jh941213/NLP/blob/main/09_Tacotron2(tutorial).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 필수 library 설치
# - PyTorch (1.5.1)
# - torchaudio

# %%
# !pip install torch
# !pip install torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Collecting torchaudio
#   Downloading https://files.pythonhosted.org/packages/96/34/c651430dea231e382ddf2eb5773239bf4885d9528f640a4ef39b12894cb8/torchaudio-0.6.0-cp36-cp36m-manylinux1_x86_64.whl (6.7MB)
#      |████████████████████████████████| 6.7MB 2.6MB/s
# Requirement already satisfied: torch==1.6.0 in /usr/local/lib/python3.6/dist-packages (from torchaudio) (1.6.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->torchaudio) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->torchaudio) (0.16.0)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-0.6.0

# %% [markdown]
# ### Code (Tacotron2)
#
# #### Reference
# - Tacotron2 (implemented by NVIDIA): https://github.com/NVIDIA/tacotron2
# - 딥러닝 기반 음성인식 기초 (T-academy): https://tacademy.skplanet.com/live/player/onlineLectureDetail.action?seq=181

# %%
import os
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import torchaudio
from torch.utils.data import Dataset, DataLoader
import numpy as np
import unicodedata
import re
import time
from torch.autograd import Variable
from math import sqrt

print('Import 완료')
# Out:
# Import 완료

# %% [markdown]
# ### 0. Hyperparameter 설정 및 device 확인
# #### batch size는 큰 값을 갖는게 좋음

# %%
class HParams():
    def __init__(self):
        self.n_mel_channels = 80

        ################################
        # Model Parameters             #
        ################################
        self.symbols_embedding_dim=512

        # Encoder parameters
        self.encoder_kernel_size=5
        self.encoder_n_convolutions=3
        self.encoder_embedding_dim=512

        # Decoder parameters
        self.n_frames_per_step=1  # currently only 1 is supported
        self.decoder_rnn_dim=1024
        self.prenet_dim=256
        self.max_decoder_steps=1000
        self.gate_threshold=0.5
        self.p_attention_dropout=0.1
        self.p_decoder_dropout=0.1

        # Attention parameters
        self.attention_rnn_dim=1024
        self.attention_dim=128

        # Location Layer parameters
        self.attention_location_n_filters=32
        self.attention_location_kernel_size=31

        # Mel-post processing network parameters
        self.postnet_embedding_dim=512
        self.postnet_kernel_size=5
        self.postnet_n_convolutions=5

        ################################
        # Optimization Hyperparameters #
        ################################
        self.use_saved_learning_rate=False
        self.learning_rate=1e-3
        self.weight_decay=1e-6
        self.grad_clip_thresh=1.0
        self.batch_size=4
        self.mask_padding=True  # set model's padded outputs to padded values
    
    
hparams = HParams()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

if torch.cuda.is_available():
  device = torch.device("cuda")
  print('GPU를 사용할 준비가 되었습니다.')
else:
  device = torch.device("cpu")
  print('CPU 모드입니다. GPU 설정으로 변경해주세요.')
# Out:
# GPU를 사용할 준비가 되었습니다.

# %% [markdown]
# ### 1. Dataset (LJ Speech) 다운로드
# #### Public data : LJ-Speech, VCTK, LibriTTS, (blizzard challenge data)

# %%
LJSpeech_url = 'https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2'
train_dataset = torchaudio.datasets.LJSPEECH("", url=LJSpeech_url, download=True)

print('Download 완료')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2748572632.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2748572632.0), HTML(value='')))
# Download 완료
# Download 완료

# %% [markdown]
# ### 2. Dataset 전처리

# %%
vocab = " abcdefghijklmnopqrstuvwxyz'.?"  # P: Padding, E: EOS.
char2idx = {char: idx for idx, char in enumerate(vocab)}
idx2char = {idx: char for idx, char in enumerate(vocab)}


def text_normalize(text):
    text = ''.join(char for char in unicodedata.normalize('NFD', text)
                   if unicodedata.category(char) != 'Mn')  # Strip accents

    text = text.lower()
    text = re.sub("[^{}]".format(vocab), " ", text)
    text = re.sub("[ ]+", " ", text)
    return text


class Collate():
  def __init__(self):
    self.wav_to_mel = torchaudio.transforms.MelSpectrogram(sample_rate=22050, n_mels=80, win_length=1024, hop_length=256, f_min=0.0, f_max=8000.0, n_fft=1024)

  def __call__(self, batch):
    # batch: N_batch * [wav, sample_rate, text, text_normalized]
    mel_list = []
    for data in batch:
      wav = data[0]
      mel_list.append(self.wav_to_mel(wav).squeeze())
    input_lengths, ids_sorted_decreasing = torch.sort(torch.LongTensor([len(data[3]) for data in batch]), dim=0, descending=True)
    mel_lengths, ids_sorted_mel = torch.sort(torch.LongTensor([mel.shape[1] for mel in mel_list]), dim=0, descending=True)

    max_input_len = input_lengths[0]
    max_target_len = mel_lengths[0]

    text_padded = torch.LongTensor(len(batch), max_input_len)
    mel_padded = torch.FloatTensor(len(batch), 80, max_target_len)
    gate_padded = torch.FloatTensor(len(batch), max_target_len)
    output_lengths = torch.LongTensor(len(batch))

    text_padded.zero_()
    mel_padded.zero_()
    gate_padded.zero_()

    for i in range(len(ids_sorted_decreasing)):
        _, _, _, text = batch[ids_sorted_decreasing[i]]
        mel = mel_list[ids_sorted_decreasing[i]]
        mel = self.dynamic_range_compression(mel)
        mel_padded[i, :, :mel.size(1)] = mel
        gate_padded[i, mel.size(1)-1:] = 1
        output_lengths[i] = mel.size(1)
        text = text_normalize(text)
        text = [char2idx[char] for char in text]
        text_norm = torch.IntTensor(text)
        text_padded[i, :len(text)] = text_norm

    return text_padded, input_lengths, mel_padded, gate_padded, output_lengths

  def dynamic_range_compression(self, x, C=1, clip_val=1e-5):
    return torch.log(torch.clamp(x, min=clip_val) * C)

collate_fn = Collate()
train_loader = DataLoader(train_dataset, batch_size=hparams.batch_size, shuffle=True, drop_last=False, collate_fn=collate_fn)

print('Data 전처리 완료')
# Out:
# Data 전처리 완료

# %% [markdown]
# ### 3. Tacotron2 모델 구현

# %% [markdown]
# #### 3-0) Basic model

# %%
def get_mask_from_lengths(lengths):
    max_len = torch.max(lengths).item()
    ids = torch.arange(0, max_len, out=torch.cuda.LongTensor(max_len))
    mask = (ids < lengths.unsqueeze(1)).bool()
    return mask


def to_gpu(x):
    x = x.contiguous() #연산과정에서 메모리에 올려진 순서에 따라 발생할 수 있는 비효율성 혹은 최악의 경우 에러를 방지하기 위함
                        #예를들어 transpose의 경우 메모리에 올려진 순서가 연속성이 깨지게되는데 메모리 접근 성능이 비효율적으로됨

    if torch.cuda.is_available():
        x = x.cuda(non_blocking=True)
    return torch.autograd.Variable(x)


class LinearNorm(torch.nn.Module):
  def __init__(self, in_dim, out_dim, bias=True, w_init_gain='linear'):
      super(LinearNorm, self).__init__()
      self.linear_layer = torch.nn.Linear(in_dim, out_dim, bias=bias)

      torch.nn.init.xavier_uniform_(
          self.linear_layer.weight,
          gain=torch.nn.init.calculate_gain(w_init_gain))

  def forward(self, x):
      return self.linear_layer(x)


class ConvNorm(torch.nn.Module):
  def __init__(self, in_channels, out_channels, kernel_size=1, stride=1,
                padding=None, dilation=1, bias=True, w_init_gain='linear'):
      super(ConvNorm, self).__init__()
      if padding is None:
          assert(kernel_size % 2 == 1)
          padding = int(dilation * (kernel_size - 1) / 2)

      self.conv = torch.nn.Conv1d(in_channels, out_channels,
                                  kernel_size=kernel_size, stride=stride,
                                  padding=padding, dilation=dilation,
                                  bias=bias)

      torch.nn.init.xavier_uniform_(
          self.conv.weight, gain=torch.nn.init.calculate_gain(w_init_gain))

  def forward(self, signal):
      conv_signal = self.conv(signal)
      return conv_signal

# %% [markdown]
# #### 3-1) Encoder
# ![image.png](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
  """Encoder module:
      - Three 1-d convolution banks
      - Bidirectional LSTM
  """
  def __init__(self, hparams):
      super(Encoder, self).__init__()

      convolutions = []
      for _ in range(hparams.encoder_n_convolutions):
          conv_layer = nn.Sequential(
              ConvNorm(hparams.encoder_embedding_dim,
                        hparams.encoder_embedding_dim,
                        kernel_size=hparams.encoder_kernel_size, stride=1,
                        padding=int((hparams.encoder_kernel_size - 1) / 2),
                        dilation=1, w_init_gain='relu'),
              nn.BatchNorm1d(hparams.encoder_embedding_dim))
          convolutions.append(conv_layer)
      self.convolutions = nn.ModuleList(convolutions)

      self.lstm = nn.LSTM(hparams.encoder_embedding_dim,
                          int(hparams.encoder_embedding_dim / 2), 1,
                          batch_first=True, bidirectional=True)

  def forward(self, x, input_lengths):
      for conv in self.convolutions:
          x = F.dropout(F.relu(conv(x)), 0.5, self.training)

      x = x.transpose(1, 2)

      # pytorch tensor are not reversible, hence the conversion
      input_lengths = input_lengths.cpu().numpy()
      x = nn.utils.rnn.pack_padded_sequence(
          x, input_lengths, batch_first=True) #병렬 처리를 위해 padded된 sequence들을 packing하는 과정, 일종의 길이에 따른 sorting 과정 더 빠른 연산 가능

      self.lstm.flatten_parameters()
      outputs, _ = self.lstm(x)

      outputs, _ = nn.utils.rnn.pad_packed_sequence(
          outputs, batch_first=True)

      return outputs

  def inference(self, x):
      for conv in self.convolutions:
          x = F.dropout(F.relu(conv(x)), 0.5, self.training)

      x = x.transpose(1, 2)

      self.lstm.flatten_parameters()
      outputs, _ = self.lstm(x)

      return outputs

# %% [markdown]
# #### 3-2) Attention
#
# ![image.png](data:image/png;base64,...)

# %%
class LocationLayer(nn.Module):
  def __init__(self, attention_n_filters, attention_kernel_size,
                attention_dim):
      super(LocationLayer, self).__init__()
      padding = int((attention_kernel_size - 1) / 2)
      self.location_conv = ConvNorm(2, attention_n_filters,
                                    kernel_size=attention_kernel_size,
                                    padding=padding, bias=False, stride=1,
                                    dilation=1)
      self.location_dense = LinearNorm(attention_n_filters, attention_dim,
                                        bias=False, w_init_gain='tanh')

  def forward(self, attention_weights_cat):
      processed_attention = self.location_conv(attention_weights_cat)
      processed_attention = processed_attention.transpose(1, 2)
      processed_attention = self.location_dense(processed_attention)
      return processed_attention


class Attention(nn.Module):
  def __init__(self, attention_rnn_dim, embedding_dim, attention_dim,
                attention_location_n_filters, attention_location_kernel_size):
      super(Attention, self).__init__()
      self.query_layer = LinearNorm(attention_rnn_dim, attention_dim,
                                    bias=False, w_init_gain='tanh')
      self.memory_layer = LinearNorm(embedding_dim, attention_dim, bias=False,
                                      w_init_gain='tanh')
      self.v = LinearNorm(attention_dim, 1, bias=False)
      self.location_layer = LocationLayer(attention_location_n_filters,
                                          attention_location_kernel_size,
                                          attention_dim)
      self.score_mask_value = -float("inf")

  def get_alignment_energies(self, query, processed_memory,
                              attention_weights_cat):
      """
      PARAMS
      ------
      query: decoder output (batch, n_mel_channels * n_frames_per_step)
      processed_memory: processed encoder outputs (B, T_in, attention_dim)
      attention_weights_cat: cumulative and prev. att weights (B, 2, max_time)

      RETURNS
      -------
      alignment (batch, max_time)
      """

      processed_query = self.query_layer(query.unsqueeze(1))
      processed_attention_weights = self.location_layer(attention_weights_cat)
      energies = self.v(torch.tanh(
          processed_query + processed_attention_weights + processed_memory))

      energies = energies.squeeze(-1)
      return energies

  def forward(self, attention_hidden_state, memory, processed_memory,
              attention_weights_cat, mask):
      """
      PARAMS
      ------
      attention_hidden_state: attention rnn last output
      memory: encoder outputs
      processed_memory: processed encoder outputs
      attention_weights_cat: previous and cummulative attention weights
      mask: binary mask for padded data
      """
      alignment = self.get_alignment_energies(
          attention_hidden_state, processed_memory, attention_weights_cat)

      if mask is not None:
          alignment.data.masked_fill_(mask, self.score_mask_value)

      attention_weights = F.softmax(alignment, dim=1)
      attention_context = torch.bmm(attention_weights.unsqueeze(1), memory) # bmm: batch matrix multiplication
      attention_context = attention_context.squeeze(1)

      return attention_context, attention_weights

# %% [markdown]
# #### 3-3) Decoder
# ![image.png](data:image/png;base64,...)

# %%
class Prenet(nn.Module):
  def __init__(self, in_dim, sizes):
      super(Prenet, self).__init__()
      in_sizes = [in_dim] + sizes[:-1]
      self.layers = nn.ModuleList(
          [LinearNorm(in_size, out_size, bias=False)
            for (in_size, out_size) in zip(in_sizes, sizes)])

  def forward(self, x):
      for linear in self.layers:
          x = F.dropout(F.relu(linear(x)), p=0.5, training=True)
      return x


class Postnet(nn.Module):
  """Postnet
      - Five 1-d convolution with 512 channels and kernel size 5
  """

  def __init__(self, hparams):
      super(Postnet, self).__init__()
      self.convolutions = nn.ModuleList()

      self.convolutions.append(
          nn.Sequential(
              ConvNorm(hparams.n_mel_channels, hparams.postnet_embedding_dim,
                        kernel_size=hparams.postnet_kernel_size, stride=1,
                        padding=int((hparams.postnet_kernel_size - 1) / 2),
                        dilation=1, w_init_gain='tanh'),
              nn.BatchNorm1d(hparams.postnet_embedding_dim))
      )

      for i in range(1, hparams.postnet_n_convolutions - 1):
          self.convolutions.append(
              nn.Sequential(
                  ConvNorm(hparams.postnet_embedding_dim,
                            hparams.postnet_embedding_dim,
                            kernel_size=hparams.postnet_kernel_size, stride=1,
                            padding=int((hparams.postnet_kernel_size - 1) / 2),
                            dilation=1, w_init_gain='tanh'),
                  nn.BatchNorm1d(hparams.postnet_embedding_dim))
          )

      self.convolutions.append(
          nn.Sequential(
              ConvNorm(hparams.postnet_embedding_dim, hparams.n_mel_channels,
                        kernel_size=hparams.postnet_kernel_size, stride=1,
                        padding=int((hparams.postnet_kernel_size - 1) / 2),
                        dilation=1, w_init_gain='linear'),
              nn.BatchNorm1d(hparams.n_mel_channels))
          )

  def forward(self, x):
      for i in range(len(self.convolutions) - 1):
          x = F.dropout(torch.tanh(self.convolutions[i](x)), 0.5, self.training)
      x = F.dropout(self.convolutions[-1](x), 0.5, self.training)

      return x


class Decoder(nn.Module):
  def __init__(self, hparams):
      super(Decoder, self).__init__()
      self.n_mel_channels = hparams.n_mel_channels
      self.n_frames_per_step = hparams.n_frames_per_step
      self.encoder_embedding_dim = hparams.encoder_embedding_dim
      self.attention_rnn_dim = hparams.attention_rnn_dim
      self.decoder_rnn_dim = hparams.decoder_rnn_dim
      self.prenet_dim = hparams.prenet_dim
      self.max_decoder_steps = hparams.max_decoder_steps
      self.gate_threshold = hparams.gate_threshold
      self.p_attention_dropout = hparams.p_attention_dropout
      self.p_decoder_dropout = hparams.p_decoder_dropout

      self.prenet = Prenet(
          hparams.n_mel_channels * hparams.n_frames_per_step,
          [hparams.prenet_dim, hparams.prenet_dim])

      self.attention_rnn = nn.LSTMCell(
          hparams.prenet_dim + hparams.encoder_embedding_dim,
          hparams.attention_rnn_dim)

      self.attention_layer = Attention(
          hparams.attention_rnn_dim, hparams.encoder_embedding_dim,
          hparams.attention_dim, hparams.attention_location_n_filters,
          hparams.attention_location_kernel_size)

      self.decoder_rnn = nn.LSTMCell(
          hparams.attention_rnn_dim + hparams.encoder_embedding_dim,
          hparams.decoder_rnn_dim, 1)

      self.linear_projection = LinearNorm(
          hparams.decoder_rnn_dim + hparams.encoder_embedding_dim,
          hparams.n_mel_channels * hparams.n_frames_per_step)

      self.gate_layer = LinearNorm(
          hparams.decoder_rnn_dim + hparams.encoder_embedding_dim, 1,
          bias=True, w_init_gain='sigmoid')

  def get_go_frame(self, memory):
      """ Gets all zeros frames to use as first decoder input
      PARAMS
      ------
      memory: decoder outputs

      RETURNS
      -------
      decoder_input: all zeros frames
      """
      B = memory.size(0)
      decoder_input = Variable(memory.data.new(
          B, self.n_mel_channels * self.n_frames_per_step).zero_())
      return decoder_input

  def initialize_decoder_states(self, memory, mask):
      """ Initializes attention rnn states, decoder rnn states, attention
      weights, attention cumulative weights, attention context, stores memory
      and stores processed memory
      PARAMS
      ------
      memory: Encoder outputs
      mask: Mask for padded data if training, expects None for inference
      """
      B = memory.size(0)
      MAX_TIME = memory.size(1)

      self.attention_hidden = Variable(memory.data.new(
          B, self.attention_rnn_dim).zero_())
      self.attention_cell = Variable(memory.data.new(
          B, self.attention_rnn_dim).zero_())

      self.decoder_hidden = Variable(memory.data.new(
          B, self.decoder_rnn_dim).zero_())
      self.decoder_cell = Variable(memory.data.new(
          B, self.decoder_rnn_dim).zero_())

      self.attention_weights = Variable(memory.data.new(
          B, MAX_TIME).zero_())
      self.attention_weights_cum = Variable(memory.data.new(
          B, MAX_TIME).zero_())
      self.attention_context = Variable(memory.data.new(
          B, self.encoder_embedding_dim).zero_())

      self.memory = memory
      self.processed_memory = self.attention_layer.memory_layer(memory)
      self.mask = mask

  def parse_decoder_inputs(self, decoder_inputs):
      """ Prepares decoder inputs, i.e. mel outputs
      PARAMS
      ------
      decoder_inputs: inputs used for teacher-forced training, i.e. mel-specs

      RETURNS
      -------
      inputs: processed decoder inputs

      """
      # (B, n_mel_channels, T_out) -> (B, T_out, n_mel_channels)
      decoder_inputs = decoder_inputs.transpose(1, 2)
      decoder_inputs = decoder_inputs.view(
          decoder_inputs.size(0),
          int(decoder_inputs.size(1)/self.n_frames_per_step), -1)
      # (B, T_out, n_mel_channels) -> (T_out, B, n_mel_channels)
      decoder_inputs = decoder_inputs.transpose(0, 1)
      return decoder_inputs

  def parse_decoder_outputs(self, mel_outputs, gate_outputs, alignments):
      """ Prepares decoder outputs for output
      PARAMS
      ------
      mel_outputs:
      gate_outputs: gate output energies
      alignments:

      RETURNS
      -------
      mel_outputs:
      gate_outpust: gate output energies
      alignments:
      """
      # (T_out, B) -> (B, T_out)
      alignments = torch.stack(alignments).transpose(0, 1)
      # (T_out, B) -> (B, T_out)
      gate_outputs = torch.stack(gate_outputs).transpose(0, 1)
      gate_outputs = gate_outputs.contiguous()
      # (T_out, B, n_mel_channels) -> (B, T_out, n_mel_channels)
      mel_outputs = torch.stack(mel_outputs).transpose(0, 1).contiguous()
      # decouple frames per step
      mel_outputs = mel_outputs.view(
          mel_outputs.size(0), -1, self.n_mel_channels)
      # (B, T_out, n_mel_channels) -> (B, n_mel_channels, T_out)
      mel_outputs = mel_outputs.transpose(1, 2)

      return mel_outputs, gate_outputs, alignments

  def decode(self, decoder_input):
      """ Decoder step using stored states, attention and memory
      PARAMS
      ------
      decoder_input: previous mel output

      RETURNS
      -------
      mel_output:
      gate_output: gate output energies
      attention_weights:
      """
      cell_input = torch.cat((decoder_input, self.attention_context), -1)
      self.attention_hidden, self.attention_cell = self.attention_rnn(
          cell_input, (self.attention_hidden, self.attention_cell))
      self.attention_hidden = F.dropout(
          self.attention_hidden, self.p_attention_dropout, self.training)

      attention_weights_cat = torch.cat(
          (self.attention_weights.unsqueeze(1),
            self.attention_weights_cum.unsqueeze(1)), dim=1)
      self.attention_context, self.attention_weights = self.attention_layer(
          self.attention_hidden, self.memory, self.processed_memory,
          attention_weights_cat, self.mask) 

      self.attention_weights_cum += self.attention_weights
      decoder_input = torch.cat(
          (self.attention_hidden, self.attention_context), -1)
      self.decoder_hidden, self.decoder_cell = self.decoder_rnn(
          decoder_input, (self.decoder_hidden, self.decoder_cell))
      self.decoder_hidden = F.dropout(
          self.decoder_hidden, self.p_decoder_dropout, self.training)

      decoder_hidden_attention_context = torch.cat(
          (self.decoder_hidden, self.attention_context), dim=1)
      decoder_output = self.linear_projection(
          decoder_hidden_attention_context)

      gate_prediction = self.gate_layer(decoder_hidden_attention_context)
      return decoder_output, gate_prediction, self.attention_weights

  def forward(self, memory, decoder_inputs, memory_lengths):
      """ Decoder forward pass for training
      PARAMS
      ------
      memory: Encoder outputs
      decoder_inputs: Decoder inputs for teacher forcing. i.e. mel-specs
      memory_lengths: Encoder output lengths for attention masking.

      RETURNS
      -------
      mel_outputs: mel outputs from the decoder
      gate_outputs: gate outputs from the decoder
      alignments: sequence of attention weights from the decoder
      """

      decoder_input = self.get_go_frame(memory).unsqueeze(0)
      decoder_inputs = self.parse_decoder_inputs(decoder_inputs)
      decoder_inputs = torch.cat((decoder_input, decoder_inputs), dim=0)
      decoder_inputs = self.prenet(decoder_inputs)

      self.initialize_decoder_states(
          memory, mask=~get_mask_from_lengths(memory_lengths))

      mel_outputs, gate_outputs, alignments = [], [], []
      while len(mel_outputs) < decoder_inputs.size(0) - 1:
          decoder_input = decoder_inputs[len(mel_outputs)]
          mel_output, gate_output, attention_weights = self.decode(
              decoder_input)
          mel_outputs += [mel_output.squeeze(1)]
          gate_outputs += [gate_output.squeeze(1)]
          alignments += [attention_weights]

      mel_outputs, gate_outputs, alignments = self.parse_decoder_outputs(
          mel_outputs, gate_outputs, alignments)

      return mel_outputs, gate_outputs, alignments

  def inference(self, memory):
      """ Decoder inference
      PARAMS
      ------
      memory: Encoder outputs

      RETURNS
      -------
      mel_outputs: mel outputs from the decoder
      gate_outputs: gate outputs from the decoder
      alignments: sequence of attention weights from the decoder
      """
      decoder_input = self.get_go_frame(memory)

      self.initialize_decoder_states(memory, mask=None)

      mel_outputs, gate_outputs, alignments = [], [], []
      while True: #free learning 모드
          decoder_input = self.prenet(decoder_input)
          mel_output, gate_output, alignment = self.decode(decoder_input)

          mel_outputs += [mel_output.squeeze(1)]
          gate_outputs += [gate_output]
          alignments += [alignment]

          if torch.sigmoid(gate_output.data) > self.gate_threshold:
              break
          elif len(mel_outputs) == self.max_decoder_steps:
              print("Warning! Reached max decoder steps")
              break

          decoder_input = mel_output

      mel_outputs, gate_outputs, alignments = self.parse_decoder_outputs(
          mel_outputs, gate_outputs, alignments)

      return mel_outputs, gate_outputs, alignments

# %% [markdown]
# #### 3-4) Tacotron2

# %%
class Tacotron2(nn.Module):
  def __init__(self, hparams):
      super(Tacotron2, self).__init__()
      self.mask_padding = hparams.mask_padding
      self.n_mel_channels = hparams.n_mel_channels
      self.n_frames_per_step = hparams.n_frames_per_step
      self.embedding = nn.Embedding(
          len(vocab), hparams.symbols_embedding_dim)
      std = sqrt(2.0 / (len(vocab) + hparams.symbols_embedding_dim))
      val = sqrt(3.0) * std  # uniform bounds for std
      self.embedding.weight.data.uniform_(-val, val)
      self.encoder = Encoder(hparams)
      self.decoder = Decoder(hparams)
      self.postnet = Postnet(hparams)

  def parse_batch(self, batch):
      text_padded, input_lengths, mel_padded, gate_padded, \
          output_lengths = batch
      text_padded = to_gpu(text_padded).long()
      input_lengths = to_gpu(input_lengths).long()
      max_len = torch.max(input_lengths.data).item()
      mel_padded = to_gpu(mel_padded).float()
      gate_padded = to_gpu(gate_padded).float()
      output_lengths = to_gpu(output_lengths).long()

      return (
          (text_padded, input_lengths, mel_padded, max_len, output_lengths),
          (mel_padded, gate_padded))

  def parse_output(self, outputs, output_lengths=None):
      if self.mask_padding and output_lengths is not None:
          mask = ~get_mask_from_lengths(output_lengths)
          mask = mask.expand(self.n_mel_channels, mask.size(0), mask.size(1))
          mask = mask.permute(1, 0, 2)

          outputs[0].data.masked_fill_(mask, 0.0)
          outputs[1].data.masked_fill_(mask, 0.0)
          outputs[2].data.masked_fill_(mask[:, 0, :], 1e3)  # gate energies

      return outputs

  def forward(self, inputs):
      text_inputs, text_lengths, mels, max_len, output_lengths = inputs
      text_lengths, output_lengths = text_lengths.data, output_lengths.data

      embedded_inputs = self.embedding(text_inputs).transpose(1, 2) #LUT

      encoder_outputs = self.encoder(embedded_inputs, text_lengths)

      mel_outputs, gate_outputs, alignments = self.decoder(
          encoder_outputs, mels, memory_lengths=text_lengths)

      mel_outputs_postnet = self.postnet(mel_outputs)
      mel_outputs_postnet = mel_outputs + mel_outputs_postnet

      return self.parse_output(
          [mel_outputs, mel_outputs_postnet, gate_outputs, alignments],
          output_lengths)

  def inference(self, inputs):
      embedded_inputs = self.embedding(inputs).transpose(1, 2)
      encoder_outputs = self.encoder.inference(embedded_inputs)
      mel_outputs, gate_outputs, alignments = self.decoder.inference(
          encoder_outputs)

      mel_outputs_postnet = self.postnet(mel_outputs)
      mel_outputs_postnet = mel_outputs + mel_ouftputs_postnet

      outputs = self.parse_output(
          [mel_outputs, mel_outputs_postnet, gate_outputs, alignments])

      return outputs

# %% [markdown]
# ### 4. 모델 선언 및 옵티마이저 설정

# %%
model = Tacotron2(hparams).to(device)
learning_rate = hparams.learning_rate
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                              weight_decay=hparams.weight_decay)

# %% [markdown]
# ### 5. 목적 함수 정의

# %%
class Tacotron2Loss(nn.Module):
  def __init__(self):
      super(Tacotron2Loss, self).__init__()

  def forward(self, model_output, targets):
      mel_target, gate_target = targets[0], targets[1]
      mel_target.requires_grad = False
      gate_target.requires_grad = False
      gate_target = gate_target.view(-1, 1)

      mel_out, mel_out_postnet, gate_out, _ = model_output
      gate_out = gate_out.view(-1, 1)
      mel_loss = nn.MSELoss()(mel_out, mel_target) + nn.MSELoss()(mel_out_postnet, mel_target)
      gate_loss = nn.BCEWithLogitsLoss()(gate_out, gate_target) #binary cross entropy (BCE보다 안정적)
      return mel_loss + gate_loss

criterion = Tacotron2Loss()

# %% [markdown]
# ### 6. 훈련

# %%
iteration = 0

for epoch in range(100):
  print("Epoch: {}".format(epoch))
  for i, batch in enumerate(train_loader):
    start = time.perf_counter()
    model.zero_grad()
    x, y = model.parse_batch(batch)
    y_pred = model(x)
    loss = criterion(y_pred, y)
    reduced_loss = loss.item()  #[1.0] -> 1.0
    loss.backward()
    grad_norm = torch.nn.utils.clip_grad_norm_(
        model.parameters(), hparams.grad_clip_thresh)

    optimizer.step()

    duration = time.perf_counter() - start
    print("Train loss {} {:.6f} Grad Norm {:.6f} {:.2f}s/it".format(
        iteration, reduced_loss, grad_norm, duration))
    
    iteration += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Train loss 8615 2.501319 Grad Norm 0.974844 2.01s/it
# Train loss 8616 2.567859 Grad Norm 1.093545 1.72s/it
# Train loss 8617 1.684396 Grad Norm 0.822558 2.11s/it
# Train loss 8618 2.474626 Grad Norm 1.387234 1.65s/it
# Train loss 8619 2.332662 Grad Norm 1.321684 2.03s/it
# Train loss 8620 2.374012 Grad Norm 1.136472 1.95s/it
# Train loss 8621 2.801786 Grad Norm 1.295998 2.19s/it
# Train loss 8622 2.341144 Grad Norm 1.193383 2.26s/it
# Train loss 8623 2.370646 Grad Norm 1.038885 2.15s/it
# Train loss 8624 2.521782 Grad Norm 1.178403 2.04s/it
# Train loss 8625 2.204786 Grad Norm 1.168916 2.28s/it
# Train loss 8626 1.953098 Grad Norm 0.989520 1.87s/it
# Train loss 8627 1.783052 Grad Norm 0.722318 2.22s/it
# Train loss 8628 2.883363 Grad Norm 1.298536 1.92s/it
# Train loss 8629 2.655273 Grad Norm 1.014091 2.22s/it
# Train loss 8630 2.021996 Grad Norm 0.842687 2.16s/it
# Train loss 8631 2.345872 Grad Norm 1.218469 2.25s/it
# Train loss 8632 2.255901 Grad Norm 1.279982 2.26s/it
# Train loss 8633 2.038141 Grad Norm 0.890698 1.53s/it
# Train loss 8634 1.848258 Grad Norm 0.871821 2.27s/it
# Train loss 8635 2.062165 Grad Norm 0.993869 1.48s/it
# Train loss 8636 2.570226 Grad Norm 1.014284 2.01s/it
# Train loss 8637 2.684188 Grad Norm 1.191736 1.90s/it
# Train loss 8638 2.226803 Grad Norm 0.998551 1.87s/it
# Train loss 8639 1.823276 Grad Norm 0.842661 2.08s/it
# Train loss 8640 2.337318 Grad Norm 0.988645 2.07s/it
# Train loss 8641 2.052616 Grad Norm 1.103007 2.07s/it
# Train loss 8642 2.660496 Grad Norm 1.782440 2.35s/it
# Train loss 8643 2.420752 Grad Norm 1.032877 1.53s/it
# Train loss 8644 2.453419 Grad Norm 2.043633 2.04s/it
# Train loss 8645 2.206325 Grad Norm 1.094094 2.05s/it
# Train loss 8646 2.616689 Grad Norm 1.161374 2.22s/it
# Train loss 8647 2.316985 Grad Norm 0.998778 2.30s/it
# Train loss 8648 1.372772 Grad Norm 0.798077 2.22s/it
# Train loss 8649 2.530890 Grad Norm 0.932857 2.24s/it
# Train loss 8650 2.243613 Grad Norm 1.151499 1.93s/it
# Train loss 8651 2.201619 Grad Norm 0.996114 2.02s/it
# Train loss 8652 2.364486 Grad Norm 1.304353 2.08s/it
# Train loss 8653 2.846781 Grad Norm 1.695905 1.85s/it
# Train loss 8654 2.444656 Grad Norm 1.003304 2.28s/it
# Train loss 8655 2.737749 Grad Norm 1.214482 1.90s/it
# Train loss 8656 2.589174 Grad Norm 1.215692 2.12s/it
# Train loss 8657 2.331114 Grad Norm 1.012005 1.87s/it
# Train loss 8658 2.517308 Grad Norm 1.185113 1.97s/it
# Train loss 8659 2.609411 Grad Norm 1.388814 1.53s/it
# Train loss 8660 2.545530 Grad Norm 0.957995 2.19s/it
# Train loss 8661 2.602920 Grad Norm 1.214097 1.69s/it
# Train loss 8662 2.725868 Grad Norm 1.021825 2.21s/it
# Train loss 8663 2.546284 Grad Norm 1.819000 1.73s/it
# Train loss 8664 2.537222 Grad Norm 1.168696 2.24s/it
# Train loss 8665 2.341025 Grad Norm 0.956919 2.22s/it
# Train loss 8666 2.549448 Grad Norm 1.609290 1.65s/it
# Train loss 8667 2.084426 Grad Norm 1.143106 2.15s/it
# Train loss 8668 2.422040 Grad Norm 1.249517 1.82s/it
# Train loss 8669 2.469834 Grad Norm 1.184682 2.20s/it
# Train loss 8670 1.577063 Grad Norm 0.922018 1.96s/it
# Train loss 8671 2.423962 Grad Norm 1.202783 1.98s/it
# Train loss 8672 2.466892 Grad Norm 0.951265 2.27s/it
# Train loss 8673 2.721786 Grad Norm 1.326772 2.29s/it
# Train loss 8674 2.519656 Grad Norm 1.217821 1.70s/it
# Train loss 8675 2.116239 Grad Norm 1.582863 2.06s/it
# Train loss 8676 2.802723 Grad Norm 1.457380 2.13s/it
# Train loss 8677 1.987360 Grad Norm 1.364606 1.81s/it
# Train loss 8678 2.044077 Grad Norm 0.983153 2.13s/it
# Train loss 8679 2.241322 Grad Norm 1.192472 2.05s/it
# Train loss 8680 2.615453 Grad Norm 1.189930 1.76s/it
# Train loss 8681 2.451500 Grad Norm 1.447778 1.69s/it
# Train loss 8682 2.389292 Grad Norm 1.452302 1.96s/it
# Train loss 8683 1.968610 Grad Norm 1.069857 2.33s/it
# Train loss 8684 1.957601 Grad Norm 1.075316 1.52s/it
# Train loss 8685 2.710535 Grad Norm 1.561802 2.22s/it
# Train loss 8686 2.148235 Grad Norm 0.897935 2.23s/it
# Train loss 8687 2.453877 Grad Norm 1.007910 2.08s/it
# Train loss 8688 2.446749 Grad Norm 0.989627 2.24s/it
# Train loss 8689 2.322188 Grad Norm 1.135679 1.90s/it
# Train loss 8690 2.373226 Grad Norm 0.920704 2.13s/it
# Train loss 8691 2.228659 Grad Norm 1.003992 1.94s/it
# Train loss 8692 1.893171 Grad Norm 0.890828 2.08s/it
# Train loss 8693 2.179843 Grad Norm 1.643437 1.92s/it
# Train loss 8694 2.374120 Grad Norm 1.511864 2.18s/it
# Train loss 8695 2.534445 Grad Norm 1.161083 2.03s/it
# Train loss 8696 1.928972 Grad Norm 1.269702 1.79s/it
# Train loss 8697 2.651656 Grad Norm 1.658766 1.82s/it
# Train loss 8698 2.867898 Grad Norm 1.909839 1.56s/it
# Train loss 8699 2.364516 Grad Norm 1.197040 1.75s/it
# Train loss 8700 1.921340 Grad Norm 0.979238 2.35s/it
# Train loss 8701 2.435773 Grad Norm 1.497015 2.19s/it
# Train loss 8702 2.405063 Grad Norm 1.510068 1.78s/it
# Train loss 8703 2.159755 Grad Norm 1.333503 1.82s/it
# Train loss 8704 2.218333 Grad Norm 1.154467 1.31s/it
# Train loss 8705 2.838765 Grad Norm 1.268021 1.93s/it
# Train loss 8706 2.291445 Grad Norm 1.194061 1.81s/it
# Train loss 8707 2.439171 Grad Norm 1.076324 1.69s/it
# Train loss 8708 2.617616 Grad Norm 0.957967 2.26s/it
# Train loss 8709 2.598697 Grad Norm 1.281059 1.89s/it
# Train loss 8710 2.661934 Grad Norm 1.807959 2.08s/it
# Train loss 8711 1.950946 Grad Norm 0.960175 2.00s/it
# Train loss 8712 2.112007 Grad Norm 0.900638 1.82s/it
# Train loss 8713 2.779104 Grad Norm 1.490342 1.65s/it
# Train loss 8714 2.298283 Grad Norm 1.448964 2.24s/it
# Train loss 8715 2.410309 Grad Norm 1.069643 1.62s/it
# Train loss 8716 2.352618 Grad Norm 1.392045 2.11s/it
# Train loss 8717 2.557845 Grad Norm 0.991340 2.14s/it
# Train loss 8718 2.190469 Grad Norm 0.965948 1.79s/it
# Train loss 8719 2.377820 Grad Norm 1.070614 1.87s/it
# Train loss 8720 2.170474 Grad Norm 0.957366 2.31s/it
# Train loss 8721 2.480267 Grad Norm 1.031718 2.24s/it
# Train loss 8722 2.209465 Grad Norm 0.945180 1.96s/it
# Train loss 8723 2.900058 Grad Norm 1.450902 1.97s/it
# Train loss 8724 2.777853 Grad Norm 1.178107 1.99s/it
# Train loss 8725 2.709398 Grad Norm 1.244392 1.83s/it
# Train loss 8726 1.988008 Grad Norm 0.963491 1.63s/it
# Train loss 8727 2.561519 Grad Norm 1.258690 1.38s/it
# Train loss 8728 2.530439 Grad Norm 1.012788 2.20s/it
# Train loss 8729 2.249503 Grad Norm 0.826431 1.84s/it
# Train loss 8730 2.772215 Grad Norm 1.395859 1.95s/it
# Train loss 8731 2.596861 Grad Norm 1.067471 1.76s/it
# Train loss 8732 2.451031 Grad Norm 1.062109 2.26s/it
# Train loss 8733 2.353358 Grad Norm 0.915728 1.96s/it
# Train loss 8734 2.136231 Grad Norm 0.984543 2.09s/it
# Train loss 8735 2.362625 Grad Norm 1.376545 1.62s/it
# Train loss 8736 2.171881 Grad Norm 0.984387 1.99s/it
# Train loss 8737 2.004361 Grad Norm 0.870236 2.19s/it
# Train loss 8738 2.514430 Grad Norm 1.086389 2.25s/it
# Train loss 8739 2.293115 Grad Norm 1.105481 2.17s/it
# Train loss 8740 1.650891 Grad Norm 0.830732 2.11s/it
# Train loss 8741 2.167134 Grad Norm 0.843298 2.07s/it
# Train loss 8742 2.864686 Grad Norm 1.136279 2.27s/it
# Train loss 8743 2.578107 Grad Norm 1.084294 2.30s/it
# Train loss 8744 2.311604 Grad Norm 0.803652 2.21s/it
# Train loss 8745 2.441316 Grad Norm 0.947844 1.96s/it
# Train loss 8746 2.186566 Grad Norm 0.949668 2.01s/it
# Train loss 8747 2.388194 Grad Norm 1.159311 1.68s/it
# Train loss 8748 1.983993 Grad Norm 1.063305 1.87s/it
# Train loss 8749 2.323308 Grad Norm 1.101266 1.94s/it
# Train loss 8750 2.495354 Grad Norm 1.005276 2.09s/it
# Train loss 8751 2.064200 Grad Norm 0.849609 2.28s/it
# Train loss 8752 1.939768 Grad Norm 0.940114 2.02s/it
# Train loss 8753 2.507171 Grad Norm 1.105948 2.03s/it
# Train loss 8754 2.404144 Grad Norm 1.084215 1.76s/it
# Train loss 8755 2.260031 Grad Norm 1.230846 2.02s/it
# Train loss 8756 2.411395 Grad Norm 0.927807 1.71s/it
# Train loss 8757 2.716115 Grad Norm 1.174163 1.94s/it
# Train loss 8758 2.614032 Grad Norm 1.379319 1.98s/it
# Train loss 8759 2.249721 Grad Norm 1.018563 1.50s/it
# Train loss 8760 2.256324 Grad Norm 1.173208 1.73s/it
# Train loss 8761 2.708712 Grad Norm 1.004340 1.68s/it
# Train loss 8762 2.222176 Grad Norm 0.883009 2.14s/it
# Train loss 8763 2.543592 Grad Norm 1.393287 1.21s/it
# Train loss 8764 1.978026 Grad Norm 1.113124 1.94s/it
# Train loss 8765 2.721632 Grad Norm 1.149925 1.83s/it
# Train loss 8766 2.902535 Grad Norm 2.881181 2.07s/it
# Train loss 8767 2.311839 Grad Norm 1.496546 2.21s/it
# Train loss 8768 2.198148 Grad Norm 1.037956 1.75s/it
# Train loss 8769 3.023908 Grad Norm 1.501499 1.99s/it
# Train loss 8770 2.619699 Grad Norm 1.635960 2.29s/it
# Train loss 8771 1.973711 Grad Norm 0.950642 2.20s/it
# Train loss 8772 2.766913 Grad Norm 1.284295 1.93s/it
# Train loss 8773 2.613404 Grad Norm 1.227089 1.96s/it
# Train loss 8774 2.736991 Grad Norm 1.062584 2.15s/it
# Train loss 8775 2.938432 Grad Norm 1.272810 2.00s/it
# Train loss 8776 2.062587 Grad Norm 0.886129 2.00s/it
# Train loss 8777 2.409817 Grad Norm 0.908117 2.17s/it
# Train loss 8778 2.798279 Grad Norm 1.105148 2.05s/it
# Train loss 8779 2.343864 Grad Norm 1.067759 2.04s/it
# Train loss 8780 2.408087 Grad Norm 1.285381 1.67s/it
# Train loss 8781 2.624030 Grad Norm 1.118607 1.93s/it
# Train loss 8782 1.733941 Grad Norm 0.870801 2.04s/it
# Train loss 8783 2.250643 Grad Norm 1.193942 2.16s/it
# Train loss 8784 2.354949 Grad Norm 1.098099 2.08s/it
# Train loss 8785 2.596003 Grad Norm 1.148784 1.44s/it
# Train loss 8786 2.466349 Grad Norm 1.135484 2.27s/it
# Train loss 8787 2.059276 Grad Norm 0.989098 2.17s/it
# Train loss 8788 2.354763 Grad Norm 1.190466 1.75s/it
# Train loss 8789 2.555407 Grad Norm 1.197499 2.30s/it
# Train loss 8790 2.023987 Grad Norm 1.042788 2.28s/it
# Train loss 8791 1.983478 Grad Norm 1.209891 2.18s/it
# Train loss 8792 2.409829 Grad Norm 1.091742 1.88s/it
# Train loss 8793 2.225166 Grad Norm 1.017106 2.05s/it
# Train loss 8794 2.616495 Grad Norm 1.227195 1.73s/it
# Train loss 8795 2.424026 Grad Norm 0.979335 2.17s/it
# Train loss 8796 2.176588 Grad Norm 1.011532 2.22s/it
# Train loss 8797 2.407295 Grad Norm 1.273045 2.13s/it
# Train loss 8798 2.656651 Grad Norm 1.015303 2.23s/it
# Train loss 8799 2.570132 Grad Norm 1.067158 1.84s/it
# Train loss 8800 1.809045 Grad Norm 0.898390 2.33s/it
# Train loss 8801 2.920177 Grad Norm 1.395858 2.00s/it
# Train loss 8802 2.231244 Grad Norm 1.027209 2.33s/it
# Train loss 8803 2.317693 Grad Norm 1.020275 2.26s/it
# Train loss 8804 1.937476 Grad Norm 0.957602 2.19s/it
# Train loss 8805 2.571273 Grad Norm 1.021045 1.92s/it
# Train loss 8806 2.713106 Grad Norm 1.514226 2.18s/it
# Train loss 8807 2.299491 Grad Norm 1.025284 2.21s/it
# Train loss 8808 1.856264 Grad Norm 0.865547 2.00s/it
# Train loss 8809 2.202333 Grad Norm 0.926873 1.94s/it
# Train loss 8810 2.216008 Grad Norm 0.954385 2.00s/it
# Train loss 8811 2.636646 Grad Norm 1.195216 2.25s/it
# Train loss 8812 2.411593 Grad Norm 1.018349 2.21s/it
# Train loss 8813 1.684235 Grad Norm 0.780770 2.03s/it
# Train loss 8814 2.090154 Grad Norm 1.102515 2.22s/it
# Train loss 8815 2.382347 Grad Norm 1.249972 2.29s/it
# Train loss 8816 2.223972 Grad Norm 0.869599 2.13s/it
# Train loss 8817 2.040695 Grad Norm 0.939669 2.05s/it
# Train loss 8818 2.432858 Grad Norm 1.352986 1.30s/it
# Train loss 8819 2.193838 Grad Norm 1.102545 1.71s/it
# Train loss 8820 2.353041 Grad Norm 0.997214 2.26s/it
# Train loss 8821 2.633887 Grad Norm 1.190369 1.94s/it
# Train loss 8822 3.096657 Grad Norm 1.814125 1.53s/it
# Train loss 8823 1.939961 Grad Norm 1.118065 1.55s/it
# Train loss 8824 2.129900 Grad Norm 1.029549 1.70s/it
# Train loss 8825 2.357727 Grad Norm 0.945655 2.11s/it
# Train loss 8826 2.005136 Grad Norm 1.027569 2.29s/it
# Train loss 8827 2.296487 Grad Norm 1.794216 1.40s/it
# Train loss 8828 2.724317 Grad Norm 1.121168 2.01s/it
# Train loss 8829 2.591025 Grad Norm 1.409985 1.57s/it
# Train loss 8830 2.277502 Grad Norm 1.060197 2.09s/it
# Train loss 8831 2.152592 Grad Norm 0.948619 2.34s/it
# Train loss 8832 2.434842 Grad Norm 1.046608 2.10s/it
# Train loss 8833 1.945184 Grad Norm 1.124572 1.86s/it
# Train loss 8834 2.045830 Grad Norm 1.264200 1.94s/it
# Train loss 8835 2.860224 Grad Norm 1.327262 1.79s/it
# Train loss 8836 1.957143 Grad Norm 1.224559 2.17s/it
# Train loss 8837 2.256890 Grad Norm 1.060259 2.28s/it
# Train loss 8838 2.240879 Grad Norm 1.031726 1.73s/it
# Train loss 8839 2.717864 Grad Norm 1.129967 2.13s/it
# Train loss 8840 2.224311 Grad Norm 1.140918 2.07s/it
# Train loss 8841 2.139189 Grad Norm 0.872938 2.04s/it
# Train loss 8842 2.563422 Grad Norm 1.280625 2.19s/it
# Train loss 8843 2.094603 Grad Norm 1.061862 2.18s/it
# Train loss 8844 2.479790 Grad Norm 1.527275 1.60s/it
# Train loss 8845 2.458915 Grad Norm 1.349015 2.10s/it
# Train loss 8846 2.648634 Grad Norm 1.350843 1.46s/it
# Train loss 8847 2.895918 Grad Norm 1.290321 1.80s/it
# Train loss 8848 2.802159 Grad Norm 1.371809 2.10s/it
# Train loss 8849 2.566869 Grad Norm 1.206959 2.28s/it
# Train loss 8850 2.465873 Grad Norm 1.051209 2.00s/it
# Train loss 8851 2.218930 Grad Norm 0.877015 2.14s/it
# Train loss 8852 2.353731 Grad Norm 1.124991 1.99s/it
# Train loss 8853 2.514354 Grad Norm 1.256525 2.14s/it
# Train loss 8854 2.373527 Grad Norm 0.993072 2.13s/it
# Train loss 8855 2.221706 Grad Norm 1.124975 1.78s/it
# Train loss 8856 2.372477 Grad Norm 0.957487 1.81s/it
# Train loss 8857 1.953526 Grad Norm 0.829550 1.98s/it
# Train loss 8858 2.602743 Grad Norm 1.308271 1.26s/it
# Train loss 8859 2.479478 Grad Norm 1.050207 2.30s/it
# Train loss 8860 2.249547 Grad Norm 1.019064 1.95s/it
# Train loss 8861 2.350355 Grad Norm 0.947060 1.35s/it
# Train loss 8862 2.609187 Grad Norm 1.056183 1.86s/it
# Train loss 8863 1.972036 Grad Norm 0.930389 2.18s/it
# Train loss 8864 2.392870 Grad Norm 1.003628 1.57s/it
# Train loss 8865 2.222938 Grad Norm 1.429752 2.08s/it
# Train loss 8866 2.748026 Grad Norm 1.253509 1.71s/it
# Train loss 8867 2.462067 Grad Norm 1.152837 1.89s/it
# Train loss 8868 1.863139 Grad Norm 0.827555 2.26s/it
# Train loss 8869 2.318533 Grad Norm 1.319829 2.24s/it
# Train loss 8870 1.942966 Grad Norm 0.994438 2.22s/it
# Train loss 8871 2.311268 Grad Norm 0.954715 1.79s/it
# Train loss 8872 1.751893 Grad Norm 1.299624 2.23s/it
# Train loss 8873 2.779635 Grad Norm 1.141610 1.92s/it
# Train loss 8874 1.630046 Grad Norm 0.802226 2.11s/it
# Train loss 8875 2.353896 Grad Norm 1.199011 2.26s/it
# Train loss 8876 2.767875 Grad Norm 1.053359 2.05s/it
# Train loss 8877 2.404694 Grad Norm 1.142350 1.79s/it
# Train loss 8878 2.435482 Grad Norm 1.041203 2.41s/it
# Train loss 8879 2.333521 Grad Norm 1.157723 2.23s/it
# Train loss 8880 2.130718 Grad Norm 0.989749 2.20s/it
# Train loss 8881 2.556746 Grad Norm 1.162053 1.91s/it
# Train loss 8882 2.108306 Grad Norm 0.971679 1.78s/it
# Train loss 8883 2.436110 Grad Norm 0.994606 2.21s/it
# Train loss 8884 2.098659 Grad Norm 1.006860 2.27s/it
# Train loss 8885 2.161114 Grad Norm 1.147660 1.68s/it
# Train loss 8886 2.936389 Grad Norm 1.068346 1.97s/it
# Train loss 8887 2.053967 Grad Norm 0.941957 2.18s/it
# Train loss 8888 2.193070 Grad Norm 0.896584 2.16s/it
# Train loss 8889 2.462716 Grad Norm 0.905464 1.90s/it
# Train loss 8890 2.850083 Grad Norm 1.115089 2.30s/it
# Train loss 8891 2.115120 Grad Norm 0.907848 2.30s/it
# Train loss 8892 2.610002 Grad Norm 0.962699 2.34s/it
# Train loss 8893 2.480630 Grad Norm 1.198823 2.13s/it
# Train loss 8894 2.836748 Grad Norm 1.137302 2.31s/it
# Train loss 8895 2.799247 Grad Norm 1.188686 2.06s/it
# Train loss 8896 2.517941 Grad Norm 1.356521 1.41s/it
# Train loss 8897 2.145102 Grad Norm 0.974172 1.99s/it
# Train loss 8898 2.628023 Grad Norm 1.454564 2.21s/it
# Train loss 8899 2.103619 Grad Norm 0.951940 1.92s/it
# Train loss 8900 2.295506 Grad Norm 1.317602 1.79s/it
# Train loss 8901 2.794052 Grad Norm 1.072730 2.19s/it
# Train loss 8902 2.806530 Grad Norm 1.676797 1.86s/it
# Train loss 8903 2.622014 Grad Norm 1.052501 1.80s/it
# Train loss 8904 2.362090 Grad Norm 1.196182 2.02s/it
# Train loss 8905 2.432884 Grad Norm 1.179313 1.29s/it
# Train loss 8906 2.306135 Grad Norm 0.955270 2.25s/it
# Train loss 8907 2.149798 Grad Norm 1.100355 2.39s/it
# Train loss 8908 2.299418 Grad Norm 1.202648 1.32s/it
# Train loss 8909 2.315188 Grad Norm 0.870896 2.30s/it
# Train loss 8910 2.609975 Grad Norm 1.362714 1.83s/it
# Train loss 8911 2.350006 Grad Norm 1.165983 2.06s/it
# Train loss 8912 2.232151 Grad Norm 0.983153 1.69s/it
# Train loss 8913 2.680904 Grad Norm 1.164223 1.78s/it
# Train loss 8914 2.107379 Grad Norm 0.842842 2.03s/it
# Train loss 8915 2.303596 Grad Norm 1.061401 2.24s/it
# Train loss 8916 2.385473 Grad Norm 1.068209 2.18s/it
# Train loss 8917 2.548869 Grad Norm 1.035115 2.11s/it
# Train loss 8918 2.153169 Grad Norm 1.056146 2.13s/it
# Train loss 8919 2.718699 Grad Norm 1.125513 1.84s/it
# Train loss 8920 2.012009 Grad Norm 1.141697 1.89s/it
# Train loss 8921 2.574786 Grad Norm 1.316497 1.84s/it
# Train loss 8922 2.593609 Grad Norm 1.188910 1.80s/it
# Train loss 8923 2.606250 Grad Norm 1.271418 1.97s/it
# Train loss 8924 2.690216 Grad Norm 1.070458 2.07s/it
# Train loss 8925 2.201515 Grad Norm 1.040506 2.14s/it
# Train loss 8926 2.246557 Grad Norm 0.954831 2.31s/it
# Train loss 8927 2.097027 Grad Norm 0.939975 1.81s/it
# Train loss 8928 2.168169 Grad Norm 1.215831 2.03s/it
# Train loss 8929 2.153445 Grad Norm 0.956192 2.29s/it
# Train loss 8930 2.396898 Grad Norm 1.031474 1.84s/it
# Train loss 8931 2.498587 Grad Norm 0.972565 2.04s/it
# Train loss 8932 1.982440 Grad Norm 1.181639 2.09s/it
# Train loss 8933 2.626330 Grad Norm 1.461192 2.03s/it
# Train loss 8934 2.181885 Grad Norm 1.165006 2.27s/it
# Train loss 8935 1.793672 Grad Norm 0.993886 2.29s/it
# Train loss 8936 2.294434 Grad Norm 1.227913 2.17s/it
# Train loss 8937 2.030524 Grad Norm 0.978404 2.13s/it
# Train loss 8938 2.249635 Grad Norm 1.039801 2.16s/it
# Train loss 8939 2.259114 Grad Norm 0.887655 2.29s/it
# Train loss 8940 2.900983 Grad Norm 1.297007 1.54s/it
# Train loss 8941 2.523481 Grad Norm 1.179990 2.26s/it
# Train loss 8942 2.202656 Grad Norm 1.106192 2.09s/it
# Train loss 8943 2.499853 Grad Norm 0.933309 2.18s/it
# Train loss 8944 2.100119 Grad Norm 1.055185 2.29s/it
# Train loss 8945 2.068727 Grad Norm 0.932999 2.12s/it
# Train loss 8946 2.730654 Grad Norm 1.081956 2.01s/it
# Train loss 8947 3.027771 Grad Norm 1.192765 2.11s/it
# Train loss 8948 2.288919 Grad Norm 1.032734 1.91s/it
# Train loss 8949 1.912191 Grad Norm 0.751090 2.30s/it
# Train loss 8950 2.220170 Grad Norm 0.884675 1.87s/it
# Train loss 8951 2.861310 Grad Norm 1.228640 2.25s/it
# Train loss 8952 2.665812 Grad Norm 1.008921 2.33s/it
# Train loss 8953 1.811347 Grad Norm 0.834162 2.23s/it
# Train loss 8954 2.478897 Grad Norm 1.086311 2.03s/it
# Train loss 8955 1.808212 Grad Norm 0.757416 2.28s/it
# Train loss 8956 2.425515 Grad Norm 1.032480 1.96s/it
# Train loss 8957 2.292225 Grad Norm 1.112680 1.89s/it
# Train loss 8958 2.601028 Grad Norm 0.942545 2.20s/it
# Train loss 8959 2.121350 Grad Norm 1.328512 2.23s/it
# Train loss 8960 2.341411 Grad Norm 1.098821 2.18s/it
# Train loss 8961 2.146035 Grad Norm 1.149078 1.24s/it
# Train loss 8962 2.209175 Grad Norm 1.039130 2.31s/it
# Train loss 8963 2.682314 Grad Norm 1.386020 2.26s/it
# Train loss 8964 2.273453 Grad Norm 1.199872 1.74s/it
# Train loss 8965 2.524214 Grad Norm 1.009269 2.35s/it
# Train loss 8966 1.716002 Grad Norm 0.872754 2.27s/it
# Train loss 8967 1.514815 Grad Norm 0.880994 2.34s/it
# Train loss 8968 2.725729 Grad Norm 1.736744 2.22s/it
# Train loss 8969 2.613346 Grad Norm 1.189425 2.26s/it
# Train loss 8970 2.417548 Grad Norm 1.094221 2.33s/it
# Train loss 8971 2.886920 Grad Norm 1.535464 1.61s/it
# Train loss 8972 2.387287 Grad Norm 1.564019 1.92s/it
# Train loss 8973 2.397588 Grad Norm 1.244289 2.26s/it
# Train loss 8974 2.878367 Grad Norm 1.336437 1.77s/it
# Train loss 8975 2.548618 Grad Norm 1.830019 1.83s/it
# Train loss 8976 2.017413 Grad Norm 1.536131 2.00s/it
# Train loss 8977 2.556407 Grad Norm 1.942443 2.10s/it
# Train loss 8978 2.527138 Grad Norm 1.204963 2.24s/it
# Train loss 8979 2.521825 Grad Norm 1.158947 1.45s/it
# Train loss 8980 2.313478 Grad Norm 1.622870 2.14s/it
# Train loss 8981 2.638342 Grad Norm 1.518141 2.05s/it
# Train loss 8982 2.337181 Grad Norm 1.218040 2.46s/it
# Train loss 8983 2.808809 Grad Norm 1.086853 2.15s/it
# Train loss 8984 2.221710 Grad Norm 1.088110 2.20s/it
# Train loss 8985 2.430274 Grad Norm 1.233835 2.04s/it
# Train loss 8986 2.596701 Grad Norm 1.090154 1.82s/it
# Train loss 8987 2.493545 Grad Norm 1.002554 1.96s/it
# Train loss 8988 2.650249 Grad Norm 1.673878 1.98s/it
# Train loss 8989 2.420902 Grad Norm 1.427683 2.26s/it
# Train loss 8990 2.184957 Grad Norm 1.311525 1.86s/it
# Train loss 8991 2.191894 Grad Norm 0.977914 2.17s/it
# Train loss 8992 2.123879 Grad Norm 1.048051 2.15s/it
# Train loss 8993 1.859948 Grad Norm 1.406426 2.37s/it
# Train loss 8994 2.528870 Grad Norm 1.105732 2.17s/it
# Train loss 8995 2.130137 Grad Norm 0.918422 2.20s/it
# Train loss 8996 2.127151 Grad Norm 1.110743 2.06s/it
# Train loss 8997 2.164591 Grad Norm 1.252725 2.16s/it
# Train loss 8998 1.857119 Grad Norm 0.800809 2.08s/it
# Train loss 8999 2.121902 Grad Norm 1.321583 2.23s/it
# Train loss 9000 2.167714 Grad Norm 0.932538 2.35s/it
# Train loss 9001 2.455586 Grad Norm 0.899423 2.26s/it
# Train loss 9002 2.348610 Grad Norm 1.046272 1.90s/it
# Train loss 9003 1.929430 Grad Norm 0.760331 2.26s/it
# Train loss 9004 1.906532 Grad Norm 1.040424 2.31s/it
# Train loss 9005 2.836315 Grad Norm 1.307400 2.03s/it
# Train loss 9006 2.667495 Grad Norm 0.986035 1.97s/it
# Train loss 9007 2.080594 Grad Norm 0.917937 1.71s/it
# Train loss 9008 2.360967 Grad Norm 0.986054 2.37s/it
# Train loss 9009 2.424723 Grad Norm 0.904862 2.34s/it
# Train loss 9010 2.421568 Grad Norm 0.993780 2.19s/it
# Train loss 9011 2.164274 Grad Norm 0.883966 2.23s/it
# Train loss 9012 2.400714 Grad Norm 1.042942 1.98s/it
# Train loss 9013 2.700145 Grad Norm 1.164990 1.75s/it
# Train loss 9014 2.240752 Grad Norm 0.940242 2.05s/it
# Train loss 9015 2.601157 Grad Norm 1.029896 1.77s/it
# Train loss 9016 2.749015 Grad Norm 1.166746 2.27s/it
# Train loss 9017 2.513527 Grad Norm 1.229185 2.22s/it
# Train loss 9018 2.415886 Grad Norm 1.081497 1.68s/it
# Train loss 9019 2.099057 Grad Norm 1.359221 2.31s/it
# Train loss 9020 1.690947 Grad Norm 0.926806 2.21s/it
# Train loss 9021 2.350923 Grad Norm 1.909220 1.44s/it
# Train loss 9022 2.576543 Grad Norm 1.091161 2.23s/it
# Train loss 9023 2.994775 Grad Norm 1.412112 1.91s/it
# Train loss 9024 2.768488 Grad Norm 1.150241 1.73s/it
# Train loss 9025 2.248622 Grad Norm 0.897415 2.22s/it
# Train loss 9026 2.663124 Grad Norm 1.144361 2.21s/it
# Train loss 9027 2.177552 Grad Norm 0.904476 1.95s/it
# Train loss 9028 1.942090 Grad Norm 0.876233 2.19s/it
# Train loss 9029 1.811719 Grad Norm 1.189685 1.94s/it
# Train loss 9030 2.422494 Grad Norm 1.010856 2.33s/it
# Train loss 9031 2.156536 Grad Norm 1.350845 2.15s/it
# Train loss 9032 2.444861 Grad Norm 1.101778 2.33s/it
# Train loss 9033 2.309457 Grad Norm 1.157188 1.88s/it
# Train loss 9034 1.718562 Grad Norm 0.817347 2.18s/it
# Train loss 9035 2.444810 Grad Norm 1.125951 1.87s/it
# Train loss 9036 2.226638 Grad Norm 1.058356 1.56s/it
# Train loss 9037 2.141790 Grad Norm 1.144203 1.99s/it
# Train loss 9038 2.985324 Grad Norm 1.984274 1.70s/it
# Train loss 9039 2.348419 Grad Norm 1.062667 1.83s/it
# Train loss 9040 2.295293 Grad Norm 1.163473 1.85s/it
# Train loss 9041 2.126662 Grad Norm 1.187666 2.18s/it
# Train loss 9042 2.345476 Grad Norm 1.111020 2.13s/it
# Train loss 9043 2.212289 Grad Norm 1.071545 2.15s/it
# Train loss 9044 3.136335 Grad Norm 1.357923 1.61s/it
# Train loss 9045 2.435412 Grad Norm 0.897672 2.03s/it
# Train loss 9046 2.187815 Grad Norm 0.905626 2.01s/it
# Train loss 9047 2.042739 Grad Norm 1.053407 2.07s/it
# Train loss 9048 2.326590 Grad Norm 1.054130 1.97s/it
# Train loss 9049 2.328138 Grad Norm 0.973282 2.03s/it
# Train loss 9050 2.225865 Grad Norm 0.856332 2.22s/it
# Train loss 9051 2.649977 Grad Norm 1.081847 2.29s/it
# Train loss 9052 2.330897 Grad Norm 1.296089 1.90s/it
# Train loss 9053 2.748003 Grad Norm 1.232276 2.15s/it
# Train loss 9054 2.088376 Grad Norm 0.963394 2.06s/it
# Train loss 9055 2.382117 Grad Norm 1.036258 2.28s/it
# Train loss 9056 2.857739 Grad Norm 1.378542 2.08s/it
# Train loss 9057 2.236690 Grad Norm 1.076447 2.13s/it
# Train loss 9058 2.155367 Grad Norm 1.182006 1.40s/it
# Train loss 9059 1.767385 Grad Norm 0.961858 2.29s/it
# Train loss 9060 2.199180 Grad Norm 1.408006 2.28s/it
# Train loss 9061 2.355460 Grad Norm 1.110917 1.47s/it
# Train loss 9062 2.809456 Grad Norm 1.601872 2.16s/it
# Train loss 9063 2.149682 Grad Norm 1.159831 1.92s/it
# Train loss 9064 1.866172 Grad Norm 0.793284 1.91s/it
# Train loss 9065 2.376007 Grad Norm 1.455756 1.98s/it
# Train loss 9066 2.525566 Grad Norm 1.063017 2.16s/it
# Train loss 9067 2.457964 Grad Norm 1.119882 1.79s/it
# Train loss 9068 2.292582 Grad Norm 1.006794 2.03s/it
# Train loss 9069 2.498934 Grad Norm 1.009050 2.25s/it
# Train loss 9070 2.368969 Grad Norm 1.024611 1.94s/it
# Train loss 9071 2.269578 Grad Norm 1.063484 1.79s/it
# Train loss 9072 2.837595 Grad Norm 1.169431 1.59s/it
# Train loss 9073 2.014931 Grad Norm 0.838034 2.16s/it
# Train loss 9074 2.019629 Grad Norm 1.010661 2.27s/it
# Train loss 9075 2.766550 Grad Norm 1.053952 1.85s/it
# Train loss 9076 2.431929 Grad Norm 1.118092 1.74s/it
# Train loss 9077 2.112669 Grad Norm 0.923649 2.18s/it
# Train loss 9078 2.262845 Grad Norm 1.023371 1.89s/it
# Train loss 9079 2.624613 Grad Norm 1.112118 1.55s/it
# Train loss 9080 1.847145 Grad Norm 0.941025 2.31s/it
# Train loss 9081 2.463539 Grad Norm 1.261682 2.16s/it
# Train loss 9082 2.687219 Grad Norm 1.104418 1.99s/it
# Train loss 9083 2.525563 Grad Norm 1.001358 1.93s/it
# Train loss 9084 2.461589 Grad Norm 1.082216 1.46s/it
# Train loss 9085 2.280218 Grad Norm 0.886294 2.21s/it
# Train loss 9086 1.602183 Grad Norm 0.855821 1.89s/it
# Train loss 9087 2.132660 Grad Norm 0.860607 1.70s/it
# Train loss 9088 2.101977 Grad Norm 1.147063 1.07s/it
# Train loss 9089 2.747380 Grad Norm 1.066274 2.06s/it
# Train loss 9090 1.842730 Grad Norm 0.774561 2.10s/it
# Train loss 9091 2.637852 Grad Norm 1.321003 1.97s/it
# Train loss 9092 2.147685 Grad Norm 1.188910 2.19s/it
# Train loss 9093 2.512192 Grad Norm 1.005661 2.21s/it
# Train loss 9094 2.700060 Grad Norm 1.119191 2.06s/it
# Train loss 9095 2.364934 Grad Norm 1.065228 2.07s/it
# Train loss 9096 2.048092 Grad Norm 0.898896 1.71s/it
# Train loss 9097 2.233261 Grad Norm 1.198776 1.58s/it
# Train loss 9098 2.479683 Grad Norm 1.119062 2.28s/it
# Train loss 9099 2.059426 Grad Norm 0.853363 2.27s/it
# Train loss 9100 2.387650 Grad Norm 1.122468 2.23s/it
# Train loss 9101 2.011665 Grad Norm 0.824542 2.20s/it
# Train loss 9102 2.167216 Grad Norm 1.000613 2.19s/it
# Train loss 9103 2.153907 Grad Norm 1.224046 1.82s/it
# Train loss 9104 2.504718 Grad Norm 1.064865 1.82s/it
# Train loss 9105 2.613190 Grad Norm 1.081221 2.05s/it
# Train loss 9106 2.081307 Grad Norm 1.505983 2.09s/it
# Train loss 9107 2.287781 Grad Norm 1.002850 2.30s/it
# Train loss 9108 2.071972 Grad Norm 0.954975 1.91s/it
# Train loss 9109 2.394682 Grad Norm 0.966490 1.98s/it
# Train loss 9110 2.408362 Grad Norm 1.171284 2.11s/it
# Train loss 9111 2.149861 Grad Norm 1.370932 2.28s/it
# Train loss 9112 2.182303 Grad Norm 0.883109 2.28s/it
# Train loss 9113 2.119226 Grad Norm 0.994094 2.05s/it
# Train loss 9114 1.678656 Grad Norm 0.870596 2.27s/it
# Train loss 9115 2.188704 Grad Norm 1.313625 1.84s/it
# Train loss 9116 2.091849 Grad Norm 1.022651 2.04s/it
# Train loss 9117 2.898241 Grad Norm 1.140720 2.24s/it
# Train loss 9118 2.502393 Grad Norm 1.279974 2.17s/it
# Train loss 9119 2.318726 Grad Norm 1.182123 2.16s/it
# Train loss 9120 2.616320 Grad Norm 1.081856 1.99s/it
# Train loss 9121 2.888926 Grad Norm 1.224714 1.99s/it
# Train loss 9122 2.933507 Grad Norm 1.254688 1.88s/it
# Train loss 9123 2.305825 Grad Norm 0.981250 1.63s/it
# Train loss 9124 2.208784 Grad Norm 0.909378 1.91s/it
# Train loss 9125 1.958754 Grad Norm 1.080000 2.03s/it
# Train loss 9126 2.120037 Grad Norm 0.911359 2.27s/it
# Train loss 9127 2.416552 Grad Norm 1.057518 2.22s/it
# Train loss 9128 2.673821 Grad Norm 1.081595 2.21s/it
# Train loss 9129 1.956808 Grad Norm 0.992979 1.70s/it
# Train loss 9130 1.909577 Grad Norm 0.800091 1.90s/it
# Train loss 9131 2.496904 Grad Norm 0.992378 2.24s/it
# Train loss 9132 1.678060 Grad Norm 0.716013 2.22s/it
# Train loss 9133 2.567382 Grad Norm 1.031963 2.25s/it
# Train loss 9134 2.021257 Grad Norm 0.912281 1.79s/it
# Train loss 9135 2.108016 Grad Norm 0.868467 2.28s/it
# Train loss 9136 2.198525 Grad Norm 0.902075 2.11s/it
# Train loss 9137 1.959259 Grad Norm 0.869332 2.10s/it
# Train loss 9138 2.455893 Grad Norm 0.981923 2.15s/it
# Train loss 9139 2.240566 Grad Norm 0.961983 1.92s/it
# Train loss 9140 2.157956 Grad Norm 0.970026 1.66s/it
# Train loss 9141 2.299755 Grad Norm 0.949607 1.95s/it
# Train loss 9142 2.263288 Grad Norm 1.959654 2.21s/it
# Train loss 9143 2.851330 Grad Norm 1.389833 1.72s/it
# Train loss 9144 2.429472 Grad Norm 1.039648 2.33s/it
# Train loss 9145 2.731918 Grad Norm 1.173081 2.10s/it
# Train loss 9146 2.529897 Grad Norm 1.127441 2.24s/it
# Train loss 9147 2.217126 Grad Norm 1.048336 2.10s/it
# Train loss 9148 2.433961 Grad Norm 0.966455 1.73s/it
# Train loss 9149 2.439187 Grad Norm 0.951921 2.27s/it
# Train loss 9150 1.880163 Grad Norm 0.788053 2.22s/it
# Train loss 9151 2.280365 Grad Norm 1.085350 1.70s/it
# Train loss 9152 2.026287 Grad Norm 1.025128 2.07s/it
# Train loss 9153 2.348986 Grad Norm 0.957658 2.21s/it
# Train loss 9154 2.350150 Grad Norm 0.935620 2.24s/it
# Train loss 9155 1.827642 Grad Norm 1.159964 1.87s/it
# Train loss 9156 2.307726 Grad Norm 0.833866 2.00s/it
# Train loss 9157 2.310198 Grad Norm 1.111781 1.82s/it
# Train loss 9158 2.118247 Grad Norm 1.034730 2.02s/it
# Train loss 9159 2.239781 Grad Norm 1.033691 2.01s/it
# Train loss 9160 2.338485 Grad Norm 1.140427 2.30s/it
# Train loss 9161 2.678758 Grad Norm 1.330981 2.04s/it
# Train loss 9162 2.506042 Grad Norm 0.999948 2.22s/it
# Train loss 9163 2.345202 Grad Norm 1.197572 1.98s/it
# Train loss 9164 2.804267 Grad Norm 1.421306 1.99s/it
# Train loss 9165 2.277906 Grad Norm 1.224215 1.92s/it
# Train loss 9166 2.288479 Grad Norm 0.937678 1.76s/it
# Train loss 9167 2.263831 Grad Norm 0.878791 2.18s/it
# Train loss 9168 2.274459 Grad Norm 1.141024 1.69s/it
# Train loss 9169 2.457615 Grad Norm 1.255953 1.61s/it
# Train loss 9170 2.269573 Grad Norm 1.111328 1.57s/it
# Train loss 9171 2.514315 Grad Norm 1.211309 1.99s/it
# Train loss 9172 2.040885 Grad Norm 1.094988 2.11s/it
# Train loss 9173 2.580077 Grad Norm 1.115147 2.30s/it
# Train loss 9174 2.131664 Grad Norm 0.957826 2.10s/it
# Train loss 9175 2.387921 Grad Norm 1.240678 1.47s/it
# Train loss 9176 2.299878 Grad Norm 1.015813 2.28s/it
# Train loss 9177 2.491113 Grad Norm 1.312535 2.15s/it
# Train loss 9178 2.558198 Grad Norm 1.361813 2.08s/it
# Train loss 9179 2.904032 Grad Norm 1.446342 1.79s/it
# Train loss 9180 2.761589 Grad Norm 1.484311 2.26s/it
# Train loss 9181 2.346349 Grad Norm 1.269601 2.28s/it
# Train loss 9182 1.479438 Grad Norm 0.761022 2.11s/it
# Train loss 9183 2.076828 Grad Norm 1.062245 2.26s/it
# Train loss 9184 1.893055 Grad Norm 1.428491 2.03s/it
# Train loss 9185 2.101142 Grad Norm 0.860631 2.05s/it
# Train loss 9186 2.645819 Grad Norm 1.094592 2.29s/it
# Train loss 9187 2.489027 Grad Norm 1.088580 2.09s/it
# Train loss 9188 2.111512 Grad Norm 0.843399 2.13s/it
# Train loss 9189 2.366143 Grad Norm 1.058065 1.52s/it
# Train loss 9190 2.433458 Grad Norm 1.033025 2.00s/it
# Train loss 9191 2.277542 Grad Norm 0.910156 1.89s/it
# Train loss 9192 2.431265 Grad Norm 1.119787 2.08s/it
# Train loss 9193 2.482005 Grad Norm 1.102410 1.85s/it
# Train loss 9194 2.473772 Grad Norm 0.991628 1.74s/it
# Train loss 9195 2.111985 Grad Norm 0.767935 1.97s/it
# Train loss 9196 2.928188 Grad Norm 1.408807 1.58s/it
# Train loss 9197 2.586947 Grad Norm 1.403806 1.84s/it
# Train loss 9198 2.379198 Grad Norm 1.135046 1.98s/it
# Train loss 9199 2.110757 Grad Norm 1.001860 1.94s/it
# Train loss 9200 2.281838 Grad Norm 1.035641 2.25s/it
# Train loss 9201 2.297818 Grad Norm 1.144136 2.08s/it
# Train loss 9202 2.016742 Grad Norm 0.923479 1.59s/it
# Train loss 9203 1.992704 Grad Norm 0.965166 2.05s/it
# Train loss 9204 2.221098 Grad Norm 1.228622 2.24s/it
# Train loss 9205 2.533864 Grad Norm 1.067064 2.01s/it
# Train loss 9206 2.296545 Grad Norm 1.079499 2.15s/it
# Train loss 9207 1.993235 Grad Norm 0.867756 1.96s/it
# Train loss 9208 2.023990 Grad Norm 0.931461 1.71s/it
# Train loss 9209 2.712406 Grad Norm 1.095468 1.93s/it
# Train loss 9210 2.391696 Grad Norm 0.991180 2.15s/it
# Train loss 9211 2.458187 Grad Norm 0.917599 1.99s/it
# Train loss 9212 1.879031 Grad Norm 0.890033 1.84s/it
# Train loss 9213 2.623343 Grad Norm 1.132945 1.66s/it
# Train loss 9214 2.682502 Grad Norm 1.155901 2.14s/it
# Train loss 9215 2.198195 Grad Norm 0.827359 2.02s/it
# Train loss 9216 2.465181 Grad Norm 1.006875 2.03s/it
# Train loss 9217 2.353632 Grad Norm 0.917701 2.16s/it
# Train loss 9218 2.090120 Grad Norm 0.935157 2.28s/it
# Train loss 9219 2.599810 Grad Norm 1.450827 1.58s/it
# Train loss 9220 1.746488 Grad Norm 0.921382 1.76s/it
# Train loss 9221 2.793061 Grad Norm 1.055073 2.07s/it
# Train loss 9222 2.429940 Grad Norm 1.271341 1.73s/it
# Train loss 9223 2.657425 Grad Norm 1.199681 1.77s/it
# Train loss 9224 2.227908 Grad Norm 0.871264 1.96s/it
# Train loss 9225 2.515085 Grad Norm 1.183878 1.82s/it
# Train loss 9226 2.232029 Grad Norm 0.918925 1.63s/it
# Train loss 9227 2.441431 Grad Norm 1.062126 1.90s/it
# Train loss 9228 2.018234 Grad Norm 0.870449 2.07s/it
# Train loss 9229 2.310088 Grad Norm 0.896235 2.09s/it
# Train loss 9230 2.152144 Grad Norm 1.041960 1.80s/it
# Train loss 9231 1.818942 Grad Norm 0.775683 2.15s/it
# Train loss 9232 2.567175 Grad Norm 1.243112 1.79s/it
# Train loss 9233 2.262497 Grad Norm 0.928961 1.74s/it
# Train loss 9234 2.473626 Grad Norm 1.067908 2.23s/it
# Train loss 9235 1.522286 Grad Norm 0.690753 2.10s/it
# Train loss 9236 1.725681 Grad Norm 0.836548 2.27s/it
# Train loss 9237 2.196317 Grad Norm 0.970982 1.70s/it
# Train loss 9238 1.855554 Grad Norm 1.023011 1.97s/it
# Train loss 9239 2.177868 Grad Norm 0.960006 2.05s/it
# Train loss 9240 3.065518 Grad Norm 1.525957 1.72s/it
# Train loss 9241 2.131661 Grad Norm 1.165492 2.07s/it
# Train loss 9242 2.712420 Grad Norm 1.441844 1.84s/it
# Train loss 9243 2.823200 Grad Norm 1.438522 2.04s/it
# Train loss 9244 2.712707 Grad Norm 1.288472 1.54s/it
# Train loss 9245 1.916251 Grad Norm 1.030235 2.09s/it
# Train loss 9246 2.190228 Grad Norm 0.905727 2.18s/it
# Train loss 9247 2.271775 Grad Norm 1.042240 2.14s/it
# Train loss 9248 2.446327 Grad Norm 0.989038 2.17s/it
# Train loss 9249 1.708733 Grad Norm 0.785355 2.07s/it
# Train loss 9250 2.832953 Grad Norm 1.261050 2.17s/it
# Train loss 9251 2.379493 Grad Norm 1.238441 2.12s/it
# Train loss 9252 1.969389 Grad Norm 0.852827 2.28s/it
# Train loss 9253 2.306378 Grad Norm 1.149698 1.99s/it
# Train loss 9254 2.155319 Grad Norm 0.969758 2.10s/it
# Train loss 9255 2.779935 Grad Norm 1.085721 1.85s/it
# Train loss 9256 2.759620 Grad Norm 1.046859 2.04s/it
# Train loss 9257 2.278249 Grad Norm 1.192070 1.17s/it
# Train loss 9258 1.881052 Grad Norm 1.103794 2.05s/it
# Train loss 9259 2.499354 Grad Norm 0.989150 2.13s/it
# Train loss 9260 1.940356 Grad Norm 0.791925 2.33s/it
# Train loss 9261 2.921044 Grad Norm 1.277986 1.75s/it
# Train loss 9262 2.786405 Grad Norm 1.248126 1.51s/it
# Train loss 9263 2.710169 Grad Norm 1.423691 1.95s/it
# Train loss 9264 2.461118 Grad Norm 1.053134 2.30s/it
# Train loss 9265 2.588468 Grad Norm 1.144099 2.22s/it
# Train loss 9266 2.182546 Grad Norm 1.196097 2.20s/it
# Train loss 9267 2.370684 Grad Norm 1.399775 1.74s/it
# Train loss 9268 2.571587 Grad Norm 1.400117 1.99s/it
# Train loss 9269 2.339991 Grad Norm 1.243075 2.13s/it
# Train loss 9270 2.415098 Grad Norm 1.982605 2.30s/it
# Train loss 9271 1.909153 Grad Norm 1.347363 2.28s/it
# Train loss 9272 2.353783 Grad Norm 1.038454 2.06s/it
# Train loss 9273 2.028814 Grad Norm 1.197745 2.18s/it
# Train loss 9274 2.381132 Grad Norm 1.630354 1.99s/it
# Train loss 9275 2.440071 Grad Norm 1.702296 2.09s/it
# Train loss 9276 2.111129 Grad Norm 0.865531 2.15s/it
# Train loss 9277 2.123357 Grad Norm 0.980023 2.04s/it
# Train loss 9278 2.413011 Grad Norm 1.599896 2.08s/it
# Train loss 9279 2.310974 Grad Norm 1.153610 2.02s/it
# Train loss 9280 2.475109 Grad Norm 1.048672 1.74s/it
# Train loss 9281 2.312101 Grad Norm 1.021542 1.92s/it
# Train loss 9282 1.921135 Grad Norm 1.139997 1.98s/it
# Train loss 9283 2.237709 Grad Norm 1.220958 1.98s/it
# Train loss 9284 2.369918 Grad Norm 1.036056 1.70s/it
# Train loss 9285 2.314523 Grad Norm 1.062407 1.88s/it
# Train loss 9286 2.483027 Grad Norm 1.208859 2.17s/it
# Train loss 9287 2.439527 Grad Norm 1.160963 1.79s/it
# Train loss 9288 2.146051 Grad Norm 1.085082 2.05s/it
# Train loss 9289 2.178726 Grad Norm 1.203429 1.90s/it
# Train loss 9290 2.665883 Grad Norm 1.127799 1.93s/it
# Train loss 9291 2.780153 Grad Norm 0.969959 1.99s/it
# Train loss 9292 2.217902 Grad Norm 0.864570 2.04s/it
# Train loss 9293 2.113861 Grad Norm 0.857675 1.84s/it
# Train loss 9294 2.271293 Grad Norm 1.082913 1.56s/it
# Train loss 9295 2.414165 Grad Norm 1.264588 1.79s/it
# Train loss 9296 2.181800 Grad Norm 1.059646 2.02s/it
# Train loss 9297 2.631623 Grad Norm 1.382467 1.52s/it
# Train loss 9298 1.913139 Grad Norm 0.821155 2.02s/it
# Train loss 9299 2.381056 Grad Norm 1.040230 2.01s/it
# Train loss 9300 2.397045 Grad Norm 1.109053 1.59s/it
# Train loss 9301 2.327897 Grad Norm 0.951010 2.00s/it
# Train loss 9302 2.903660 Grad Norm 1.048757 2.10s/it
# Train loss 9303 2.378525 Grad Norm 1.002571 1.94s/it
# Train loss 9304 2.229980 Grad Norm 0.936801 1.63s/it
# Train loss 9305 2.426231 Grad Norm 1.024558 2.47s/it
# Train loss 9306 2.194321 Grad Norm 0.956898 2.03s/it
# Train loss 9307 2.055962 Grad Norm 0.869482 2.30s/it
# Train loss 9308 2.264309 Grad Norm 0.952359 2.28s/it
# Train loss 9309 2.355576 Grad Norm 1.069245 2.22s/it
# Train loss 9310 2.367998 Grad Norm 0.852860 2.32s/it
# Train loss 9311 2.033512 Grad Norm 0.964660 2.22s/it
# Train loss 9312 1.967273 Grad Norm 0.919335 1.71s/it
# Train loss 9313 2.353183 Grad Norm 1.007075 2.25s/it
# Train loss 9314 2.467922 Grad Norm 1.135892 1.85s/it
# Train loss 9315 2.953166 Grad Norm 1.100630 2.22s/it
# Train loss 9316 2.228982 Grad Norm 1.007051 2.27s/it
# Train loss 9317 2.541767 Grad Norm 1.112262 1.50s/it
# Train loss 9318 2.649238 Grad Norm 0.987019 2.08s/it
# Train loss 9319 2.413583 Grad Norm 1.319070 1.76s/it
# Train loss 9320 2.574306 Grad Norm 1.672815 1.98s/it
# Train loss 9321 2.355650 Grad Norm 1.094154 2.15s/it
# Train loss 9322 2.744923 Grad Norm 1.441553 1.98s/it
# Train loss 9323 2.470189 Grad Norm 1.291017 1.30s/it
# Train loss 9324 1.848287 Grad Norm 0.909446 1.81s/it
# Train loss 9325 2.563596 Grad Norm 1.174816 1.45s/it
# Train loss 9326 2.470780 Grad Norm 1.155900 2.17s/it
# Train loss 9327 2.383206 Grad Norm 1.168513 1.98s/it
# Train loss 9328 2.472410 Grad Norm 1.196959 1.80s/it
# Train loss 9329 2.738750 Grad Norm 1.131207 2.23s/it
# Train loss 9330 2.760610 Grad Norm 1.652069 1.76s/it
# Train loss 9331 3.140132 Grad Norm 1.523628 1.45s/it
# Train loss 9332 2.705130 Grad Norm 1.145587 2.04s/it
# Train loss 9333 2.043324 Grad Norm 0.839394 2.28s/it
# Train loss 9334 1.949959 Grad Norm 0.767030 2.25s/it
# Train loss 9335 2.673500 Grad Norm 0.971713 1.93s/it
# Train loss 9336 2.122978 Grad Norm 0.974868 1.85s/it
# Train loss 9337 2.492971 Grad Norm 1.128127 1.91s/it
# Train loss 9338 2.791208 Grad Norm 1.189966 2.22s/it
# Train loss 9339 2.190327 Grad Norm 1.264611 1.47s/it
# Train loss 9340 2.214830 Grad Norm 0.982333 2.02s/it
# Train loss 9341 1.811530 Grad Norm 0.860677 2.13s/it
# Train loss 9342 2.585475 Grad Norm 1.273484 1.94s/it
# Train loss 9343 1.966664 Grad Norm 0.929069 1.76s/it
# Train loss 9344 2.647779 Grad Norm 1.166625 1.91s/it
# Train loss 9345 2.418895 Grad Norm 1.106825 1.84s/it
# Train loss 9346 2.613186 Grad Norm 1.149295 2.21s/it
# Train loss 9347 2.262358 Grad Norm 1.063924 2.30s/it
# Train loss 9348 1.917398 Grad Norm 1.041571 2.04s/it
# Train loss 9349 2.404784 Grad Norm 1.114636 2.13s/it
# Train loss 9350 2.004123 Grad Norm 0.984348 2.37s/it
# Train loss 9351 2.245213 Grad Norm 1.090318 1.99s/it
# Train loss 9352 2.491009 Grad Norm 1.685402 2.30s/it
# Train loss 9353 2.481697 Grad Norm 1.130503 2.17s/it
# Train loss 9354 1.881615 Grad Norm 0.928846 1.90s/it
# Train loss 9355 2.749074 Grad Norm 1.271875 1.60s/it
# Train loss 9356 2.217847 Grad Norm 0.892506 2.24s/it
# Train loss 9357 2.275113 Grad Norm 1.089706 1.68s/it
# Train loss 9358 2.155398 Grad Norm 1.070613 1.47s/it
# Train loss 9359 1.900732 Grad Norm 0.875891 1.63s/it
# Train loss 9360 2.216682 Grad Norm 0.923502 1.85s/it
# Train loss 9361 2.362963 Grad Norm 0.967134 1.96s/it
# Train loss 9362 2.881134 Grad Norm 1.384685 2.05s/it
# Train loss 9363 2.673303 Grad Norm 1.293296 2.15s/it
# Train loss 9364 2.325439 Grad Norm 1.149801 1.96s/it
# Train loss 9365 2.401349 Grad Norm 1.342450 1.90s/it
# Train loss 9366 2.430736 Grad Norm 1.052169 1.86s/it
# Train loss 9367 2.243817 Grad Norm 0.872591 2.02s/it
# Train loss 9368 2.292382 Grad Norm 0.956751 1.92s/it
# Train loss 9369 2.004186 Grad Norm 0.935961 2.21s/it
# Train loss 9370 2.143727 Grad Norm 0.824607 2.13s/it
# Train loss 9371 2.860627 Grad Norm 1.665039 1.75s/it
# Train loss 9372 1.745650 Grad Norm 0.893037 2.11s/it
# Train loss 9373 2.654244 Grad Norm 0.911631 2.08s/it
# Train loss 9374 2.434099 Grad Norm 0.949615 2.06s/it
# Train loss 9375 2.313501 Grad Norm 0.984375 2.30s/it
# Train loss 9376 2.207887 Grad Norm 0.876955 1.77s/it
# Train loss 9377 2.145911 Grad Norm 0.908112 1.67s/it
# Train loss 9378 2.303346 Grad Norm 1.017816 1.67s/it
# Train loss 9379 2.472208 Grad Norm 1.201779 1.77s/it
# Train loss 9380 1.956820 Grad Norm 1.057105 1.53s/it
# Train loss 9381 2.477684 Grad Norm 0.910552 1.90s/it
# Train loss 9382 2.459964 Grad Norm 1.087129 2.24s/it
# Train loss 9383 2.303932 Grad Norm 1.043563 2.19s/it
# Train loss 9384 1.875650 Grad Norm 0.815887 1.76s/it
# Train loss 9385 1.910418 Grad Norm 0.827783 2.18s/it
# Train loss 9386 2.527326 Grad Norm 1.293365 1.70s/it
# Train loss 9387 2.066716 Grad Norm 1.161622 1.65s/it
# Train loss 9388 1.375111 Grad Norm 0.659471 2.00s/it
# Train loss 9389 2.562431 Grad Norm 1.682112 1.79s/it
# Train loss 9390 1.962342 Grad Norm 1.620191 2.14s/it
# Train loss 9391 1.954468 Grad Norm 0.894477 1.93s/it
# Train loss 9392 2.333274 Grad Norm 1.260086 2.14s/it
# Train loss 9393 2.580142 Grad Norm 1.179260 1.88s/it
# Train loss 9394 1.836751 Grad Norm 1.096065 1.94s/it
# Train loss 9395 2.766921 Grad Norm 1.838667 1.49s/it
# Train loss 9396 2.646987 Grad Norm 1.264430 1.98s/it
# Train loss 9397 2.542859 Grad Norm 1.160674 1.80s/it
# Train loss 9398 2.266321 Grad Norm 1.225924 2.16s/it
# Train loss 9399 1.998345 Grad Norm 1.277959 2.08s/it
# Train loss 9400 2.016454 Grad Norm 1.040882 1.84s/it
# Train loss 9401 1.971087 Grad Norm 0.974576 2.13s/it
# Train loss 9402 2.787666 Grad Norm 1.649577 1.52s/it
# Train loss 9403 2.047229 Grad Norm 1.016172 2.21s/it
# Train loss 9404 2.072052 Grad Norm 0.877037 1.65s/it
# Train loss 9405 2.581578 Grad Norm 1.002123 1.77s/it
# Train loss 9406 2.807304 Grad Norm 1.187793 1.92s/it
# Train loss 9407 2.068920 Grad Norm 1.118880 1.24s/it
# Train loss 9408 2.326594 Grad Norm 1.084114 1.62s/it
# Train loss 9409 2.798590 Grad Norm 1.518790 2.22s/it
# Train loss 9410 2.402602 Grad Norm 1.149176 1.07s/it
# Train loss 9411 2.772168 Grad Norm 1.043722 2.16s/it
# Train loss 9412 2.552470 Grad Norm 1.124436 2.27s/it
# Train loss 9413 1.646460 Grad Norm 0.715485 1.79s/it
# Train loss 9414 2.341256 Grad Norm 1.403098 1.43s/it
# Train loss 9415 2.262480 Grad Norm 1.094485 1.99s/it
# Train loss 9416 2.236352 Grad Norm 1.014913 2.04s/it
# Train loss 9417 2.693192 Grad Norm 0.981282 2.11s/it
# Train loss 9418 2.222236 Grad Norm 0.937078 2.35s/it
# Train loss 9419 2.396014 Grad Norm 1.119608 2.18s/it
# Train loss 9420 1.760219 Grad Norm 0.751910 2.16s/it
# Train loss 9421 2.538428 Grad Norm 1.128351 1.53s/it
# Train loss 9422 2.623199 Grad Norm 1.288211 2.04s/it
# Train loss 9423 2.635883 Grad Norm 1.063794 2.24s/it
# Train loss 9424 2.252112 Grad Norm 1.145249 2.20s/it
# Train loss 9425 1.830568 Grad Norm 0.807888 2.36s/it
# Train loss 9426 2.739156 Grad Norm 1.215881 2.00s/it
# Train loss 9427 2.673250 Grad Norm 1.054617 2.10s/it
# Train loss 9428 2.366561 Grad Norm 0.927701 2.27s/it
# Train loss 9429 1.816703 Grad Norm 0.929107 2.29s/it
# Train loss 9430 2.265565 Grad Norm 0.911350 1.84s/it
# Train loss 9431 2.242506 Grad Norm 1.024591 2.21s/it
# Train loss 9432 2.580865 Grad Norm 0.987773 1.82s/it
# Train loss 9433 2.392272 Grad Norm 0.959664 2.32s/it
# Train loss 9434 2.366082 Grad Norm 1.132295 1.96s/it
# Train loss 9435 2.296357 Grad Norm 0.900769 1.84s/it
# Train loss 9436 2.812214 Grad Norm 1.216164 2.12s/it
# Train loss 9437 2.398171 Grad Norm 0.974129 2.23s/it
# Train loss 9438 2.928532 Grad Norm 1.148823 1.96s/it
# Train loss 9439 1.961154 Grad Norm 0.893651 2.17s/it
# Train loss 9440 2.601861 Grad Norm 1.302745 1.64s/it
# Train loss 9441 2.506375 Grad Norm 1.005687 1.91s/it
# Train loss 9442 1.636485 Grad Norm 0.841078 2.10s/it
# Train loss 9443 1.946608 Grad Norm 0.972119 2.21s/it
# Train loss 9444 2.286816 Grad Norm 1.345603 2.02s/it
# Train loss 9445 2.338216 Grad Norm 1.055383 1.87s/it
# Train loss 9446 2.180882 Grad Norm 1.095594 2.14s/it
# Train loss 9447 2.665176 Grad Norm 1.702160 2.03s/it
# Train loss 9448 2.081465 Grad Norm 0.959973 1.92s/it
# Train loss 9449 2.022680 Grad Norm 0.946575 2.07s/it
# Train loss 9450 1.798433 Grad Norm 0.817933 2.24s/it
# Train loss 9451 2.391749 Grad Norm 1.504884 1.85s/it
# Train loss 9452 2.549891 Grad Norm 2.057464 1.87s/it
# Train loss 9453 2.147183 Grad Norm 1.363897 2.13s/it
# Train loss 9454 2.563696 Grad Norm 1.093242 2.03s/it
# Train loss 9455 1.838560 Grad Norm 1.159686 1.25s/it
# Train loss 9456 2.344469 Grad Norm 1.591519 1.61s/it
# Train loss 9457 2.697903 Grad Norm 1.536791 1.46s/it
# Train loss 9458 2.008087 Grad Norm 0.887236 2.11s/it
# Train loss 9459 2.151621 Grad Norm 0.948519 1.93s/it
# Train loss 9460 2.008157 Grad Norm 1.170236 1.95s/it
# Train loss 9461 2.482220 Grad Norm 1.135662 2.25s/it
# Train loss 9462 2.382543 Grad Norm 0.956387 1.70s/it
# Train loss 9463 2.411271 Grad Norm 0.961228 1.90s/it
# Train loss 9464 1.946203 Grad Norm 0.996752 2.01s/it
# Train loss 9465 2.856390 Grad Norm 1.809184 1.95s/it
# Train loss 9466 2.342437 Grad Norm 1.221282 1.72s/it
# Train loss 9467 2.192607 Grad Norm 1.157799 1.87s/it
# Train loss 9468 2.675372 Grad Norm 1.013042 2.14s/it
# Train loss 9469 1.869417 Grad Norm 1.221289 1.86s/it
# Train loss 9470 2.338074 Grad Norm 1.085109 1.70s/it
# Train loss 9471 2.400537 Grad Norm 1.408870 1.25s/it
# Train loss 9472 1.922365 Grad Norm 0.788036 2.11s/it
# Train loss 9473 2.441939 Grad Norm 1.338257 1.95s/it
# Train loss 9474 2.827254 Grad Norm 1.470004 1.97s/it
# Train loss 9475 2.593482 Grad Norm 1.334115 1.96s/it
# Train loss 9476 2.043986 Grad Norm 1.056240 2.04s/it
# Train loss 9477 2.486052 Grad Norm 1.515877 1.83s/it
# Train loss 9478 2.612558 Grad Norm 1.186575 2.22s/it
# Train loss 9479 2.300104 Grad Norm 1.418903 1.83s/it
# Train loss 9480 2.287086 Grad Norm 1.383374 1.49s/it
# Train loss 9481 2.303062 Grad Norm 1.111639 1.92s/it
# Train loss 9482 2.559051 Grad Norm 1.076992 2.13s/it
# Train loss 9483 2.665350 Grad Norm 1.105104 2.19s/it
# Train loss 9484 2.148208 Grad Norm 1.045141 1.83s/it
# Train loss 9485 2.441195 Grad Norm 1.132764 2.21s/it
# Train loss 9486 2.428904 Grad Norm 1.409121 1.59s/it
# Train loss 9487 2.779317 Grad Norm 1.154248 1.95s/it
# Train loss 9488 2.077264 Grad Norm 2.609705 2.07s/it
# Train loss 9489 2.758681 Grad Norm 1.304052 2.12s/it
# Train loss 9490 2.258581 Grad Norm 1.784526 1.99s/it
# Train loss 9491 2.087760 Grad Norm 0.846870 2.03s/it
# Train loss 9492 2.782057 Grad Norm 1.107728 1.68s/it
# Train loss 9493 1.985727 Grad Norm 0.825321 2.08s/it
# Train loss 9494 1.991082 Grad Norm 1.349027 2.18s/it
# Train loss 9495 2.402114 Grad Norm 1.369842 2.15s/it
# Train loss 9496 2.344121 Grad Norm 0.938908 2.19s/it
# Train loss 9497 2.514765 Grad Norm 1.053408 1.76s/it
# Train loss 9498 2.261246 Grad Norm 1.380441 1.98s/it
# Train loss 9499 1.937569 Grad Norm 0.904986 1.60s/it
# Train loss 9500 2.270857 Grad Norm 1.108089 2.45s/it
# Train loss 9501 2.602355 Grad Norm 1.289853 1.47s/it
# Train loss 9502 2.485265 Grad Norm 1.053797 2.30s/it
# Train loss 9503 2.655962 Grad Norm 1.382064 1.79s/it
# Train loss 9504 2.109989 Grad Norm 0.998493 1.92s/it
# Train loss 9505 2.845163 Grad Norm 1.120219 2.11s/it
# Train loss 9506 2.556279 Grad Norm 1.281400 1.50s/it
# Train loss 9507 2.718962 Grad Norm 1.169036 1.96s/it
# Train loss 9508 2.071176 Grad Norm 0.991161 1.53s/it
# Train loss 9509 1.979897 Grad Norm 1.008270 2.17s/it
# Train loss 9510 2.407323 Grad Norm 1.169239 2.20s/it
# Train loss 9511 1.979293 Grad Norm 0.975808 1.80s/it
# Train loss 9512 2.225496 Grad Norm 1.274052 2.02s/it
# Train loss 9513 2.169731 Grad Norm 0.866884 2.05s/it
# Train loss 9514 2.469689 Grad Norm 1.147855 2.20s/it
# Train loss 9515 2.404871 Grad Norm 1.125563 1.86s/it
# Train loss 9516 2.427491 Grad Norm 0.891701 2.16s/it
# Train loss 9517 2.579727 Grad Norm 0.939159 2.16s/it
# Train loss 9518 2.402012 Grad Norm 1.257419 1.77s/it
# ...
# Train loss 13341 2.307046 Grad Norm 1.103377 1.72s/it
# Train loss 13342 1.862596 Grad Norm 0.915624 1.75s/it
# Train loss 13343 2.190927 Grad Norm 1.302417 2.24s/it
# Train loss 13344 1.931734 Grad Norm 0.897252 1.79s/it
# Train loss 13345 2.383296 Grad Norm 1.257885 1.80s/it
# Train loss 13346 2.334888 Grad Norm 1.142306 1.95s/it
# Train loss 13347 2.401107 Grad Norm 1.038241 2.07s/it
# Train loss 13348 1.966057 Grad Norm 0.857799 1.99s/it
# Train loss 13349 2.244549 Grad Norm 0.948376 1.88s/it
# Train loss 13350 1.796514 Grad Norm 0.804762 2.17s/it
# Train loss 13351 2.402891 Grad Norm 1.136284 1.88s/it
# Train loss 13352 2.019413 Grad Norm 1.130727 1.42s/it
# Train loss 13353 2.472258 Grad Norm 1.028242 1.80s/it
# Train loss 13354 1.998910 Grad Norm 0.849557 2.22s/it
# Train loss 13355 2.106731 Grad Norm 0.935038 2.05s/it
# Train loss 13356 2.055138 Grad Norm 1.193923 1.92s/it
# Train loss 13357 2.215106 Grad Norm 1.111280 1.91s/it
# Train loss 13358 2.027577 Grad Norm 0.866545 1.88s/it
# Train loss 13359 2.143985 Grad Norm 0.977939 2.18s/it
# Train loss 13360 1.968540 Grad Norm 0.882423 2.24s/it
# Train loss 13361 1.870310 Grad Norm 0.996886 2.08s/it
# Train loss 13362 2.304093 Grad Norm 1.085493 1.74s/it
# Train loss 13363 2.164798 Grad Norm 1.368553 1.76s/it
# Train loss 13364 2.091389 Grad Norm 1.098304 1.95s/it
# Train loss 13365 1.826975 Grad Norm 1.046609 2.06s/it
# Train loss 13366 2.391781 Grad Norm 1.139004 2.10s/it
# Train loss 13367 1.615765 Grad Norm 0.912370 1.47s/it
# Train loss 13368 2.259596 Grad Norm 1.160629 1.31s/it
# Train loss 13369 2.332075 Grad Norm 1.008621 2.04s/it
# Train loss 13370 2.132953 Grad Norm 1.204784 2.06s/it
# Train loss 13371 2.605708 Grad Norm 1.486545 2.15s/it
# Train loss 13372 1.968570 Grad Norm 1.101087 2.28s/it
# Train loss 13373 1.663967 Grad Norm 0.796085 1.90s/it
# Train loss 13374 2.348674 Grad Norm 1.286928 1.69s/it
# Train loss 13375 2.230485 Grad Norm 1.130706 1.83s/it
# Train loss 13376 2.075318 Grad Norm 0.915521 2.25s/it
# Train loss 13377 1.910345 Grad Norm 0.952518 1.85s/it
# Train loss 13378 2.596740 Grad Norm 1.120584 1.61s/it
# Train loss 13379 2.224246 Grad Norm 1.072899 2.20s/it
# Train loss 13380 1.857569 Grad Norm 0.840717 1.99s/it
# Train loss 13381 2.147563 Grad Norm 0.943174 1.95s/it
# Train loss 13382 2.477684 Grad Norm 0.893436 2.06s/it
# Train loss 13383 2.290058 Grad Norm 0.984337 2.12s/it
# Train loss 13384 2.083389 Grad Norm 0.894641 1.90s/it
# Train loss 13385 2.664146 Grad Norm 1.118906 2.22s/it
# Train loss 13386 2.560374 Grad Norm 1.153996 1.90s/it
# Train loss 13387 1.831576 Grad Norm 0.881353 2.02s/it
# Train loss 13388 2.342659 Grad Norm 1.242449 2.28s/it
# Train loss 13389 2.690503 Grad Norm 1.282798 1.88s/it
# Train loss 13390 1.847358 Grad Norm 0.902390 2.02s/it
# Train loss 13391 2.094970 Grad Norm 1.270809 1.78s/it
# Train loss 13392 1.760311 Grad Norm 0.810314 2.01s/it
# Train loss 13393 1.980158 Grad Norm 0.909268 2.15s/it
# Train loss 13394 2.104286 Grad Norm 0.917610 1.67s/it
# Train loss 13395 1.943081 Grad Norm 1.131975 1.94s/it
# Train loss 13396 2.140330 Grad Norm 0.956258 1.95s/it
# Train loss 13397 2.394243 Grad Norm 1.026419 1.95s/it
# Train loss 13398 1.562675 Grad Norm 0.759722 1.97s/it
# Train loss 13399 2.188599 Grad Norm 1.302928 1.47s/it
# Train loss 13400 2.622140 Grad Norm 1.582500 1.52s/it
# Train loss 13401 1.821093 Grad Norm 1.080852 1.95s/it
# Train loss 13402 2.179054 Grad Norm 1.035105 2.19s/it
# Train loss 13403 2.469886 Grad Norm 1.234615 2.04s/it
# Train loss 13404 2.399949 Grad Norm 1.135265 1.61s/it
# Train loss 13405 2.331526 Grad Norm 1.089275 2.05s/it
# Train loss 13406 2.433398 Grad Norm 1.104783 2.21s/it
# Train loss 13407 2.241824 Grad Norm 0.973193 2.09s/it
# Train loss 13408 2.202935 Grad Norm 1.186454 1.96s/it
# Train loss 13409 2.105468 Grad Norm 0.894444 2.15s/it
# Train loss 13410 2.185755 Grad Norm 0.950413 1.99s/it
# Train loss 13411 2.104644 Grad Norm 0.972897 2.16s/it
# Train loss 13412 1.951635 Grad Norm 1.009068 2.19s/it
# Train loss 13413 2.447221 Grad Norm 1.065924 2.05s/it
# Train loss 13414 1.977228 Grad Norm 0.781878 2.20s/it
# Train loss 13415 1.616936 Grad Norm 0.936946 2.03s/it
# Train loss 13416 2.526242 Grad Norm 1.025269 2.13s/it
# Train loss 13417 1.900705 Grad Norm 0.889569 1.89s/it
# Train loss 13418 1.713279 Grad Norm 0.834451 1.48s/it
# Train loss 13419 1.752103 Grad Norm 0.904337 1.80s/it
# Train loss 13420 2.461576 Grad Norm 0.984387 2.08s/it
# Train loss 13421 1.862991 Grad Norm 1.118861 1.78s/it
# Train loss 13422 1.923746 Grad Norm 0.791038 2.18s/it
# Train loss 13423 2.380628 Grad Norm 1.150566 1.73s/it
# Train loss 13424 1.614550 Grad Norm 0.782084 1.89s/it
# Train loss 13425 2.373066 Grad Norm 1.107358 1.71s/it
# Train loss 13426 1.917084 Grad Norm 0.891219 2.27s/it
# Train loss 13427 1.949721 Grad Norm 0.981496 2.14s/it
# Train loss 13428 2.338313 Grad Norm 1.009138 1.67s/it
# Train loss 13429 2.207573 Grad Norm 1.284723 1.66s/it
# Train loss 13430 2.063073 Grad Norm 0.994258 1.89s/it
# Train loss 13431 1.654491 Grad Norm 0.725694 2.10s/it
# Train loss 13432 2.645884 Grad Norm 1.046415 2.01s/it
# Train loss 13433 1.984513 Grad Norm 1.045903 1.95s/it
# Train loss 13434 2.029386 Grad Norm 1.041319 2.17s/it
# Train loss 13435 2.223695 Grad Norm 1.006384 2.05s/it
# Train loss 13436 2.625300 Grad Norm 0.990188 2.10s/it
# Train loss 13437 2.358649 Grad Norm 1.028973 2.15s/it
# Train loss 13438 2.476967 Grad Norm 0.918215 2.22s/it
# Train loss 13439 2.530797 Grad Norm 0.972723 2.31s/it
# Train loss 13440 2.241999 Grad Norm 0.915310 2.23s/it
# Train loss 13441 2.455612 Grad Norm 1.304200 1.47s/it
# Train loss 13442 2.569216 Grad Norm 1.089419 1.91s/it
# Train loss 13443 2.074710 Grad Norm 0.965028 2.00s/it
# Train loss 13444 2.718033 Grad Norm 1.107958 1.88s/it
# Train loss 13445 1.872481 Grad Norm 0.851360 2.17s/it
# Train loss 13446 2.287781 Grad Norm 1.069321 2.11s/it
# Train loss 13447 2.715652 Grad Norm 1.283767 1.66s/it
# Train loss 13448 1.949230 Grad Norm 0.922748 1.33s/it
# Train loss 13449 2.485242 Grad Norm 1.168449 2.07s/it
# Train loss 13450 2.135602 Grad Norm 0.967965 1.93s/it
# Train loss 13451 2.424684 Grad Norm 0.963998 2.13s/it
# Train loss 13452 2.388396 Grad Norm 1.208982 2.26s/it
# Train loss 13453 1.695655 Grad Norm 0.924648 2.07s/it
# Train loss 13454 2.311192 Grad Norm 0.971386 2.08s/it
# Train loss 13455 1.826588 Grad Norm 0.744770 2.17s/it
# Train loss 13456 2.119814 Grad Norm 0.974168 2.20s/it
# Train loss 13457 2.121644 Grad Norm 0.968915 2.17s/it
# Train loss 13458 2.108783 Grad Norm 0.966588 1.77s/it
# Train loss 13459 2.058097 Grad Norm 1.143766 2.21s/it
# Train loss 13460 2.407161 Grad Norm 1.255161 2.28s/it
# Train loss 13461 2.497413 Grad Norm 1.240809 1.77s/it
# Train loss 13462 2.237319 Grad Norm 1.217177 1.79s/it
# Train loss 13463 2.118122 Grad Norm 1.379653 2.03s/it
# Train loss 13464 2.525884 Grad Norm 1.052159 2.03s/it
# Train loss 13465 2.210215 Grad Norm 1.008002 1.82s/it
# Train loss 13466 2.001147 Grad Norm 1.018452 2.18s/it
# Train loss 13467 2.601988 Grad Norm 1.074941 1.88s/it
# Train loss 13468 1.994059 Grad Norm 1.037932 1.75s/it
# Train loss 13469 2.348983 Grad Norm 0.865247 2.27s/it
# Train loss 13470 1.890525 Grad Norm 0.846545 1.92s/it
# Train loss 13471 2.178626 Grad Norm 0.954699 1.75s/it
# Train loss 13472 2.138737 Grad Norm 1.148702 2.31s/it
# Train loss 13473 1.933117 Grad Norm 0.964882 2.13s/it
# Train loss 13474 2.155226 Grad Norm 0.903463 2.21s/it
# Train loss 13475 2.460226 Grad Norm 1.191537 1.92s/it
# Train loss 13476 2.543125 Grad Norm 1.802052 1.73s/it
# Train loss 13477 1.521237 Grad Norm 0.844451 1.77s/it
# Train loss 13478 2.501021 Grad Norm 0.952226 2.29s/it
# Train loss 13479 2.505291 Grad Norm 1.578953 1.96s/it
# Train loss 13480 2.091285 Grad Norm 1.021087 1.97s/it
# Train loss 13481 2.476418 Grad Norm 1.248772 2.23s/it
# Train loss 13482 2.320491 Grad Norm 1.198162 1.49s/it
# Train loss 13483 2.122968 Grad Norm 0.918899 2.17s/it
# Train loss 13484 2.364912 Grad Norm 1.527893 2.03s/it
# Train loss 13485 2.141524 Grad Norm 1.021706 2.14s/it
# Train loss 13486 2.008680 Grad Norm 0.997549 2.35s/it
# Train loss 13487 1.939416 Grad Norm 1.003257 2.17s/it
# Train loss 13488 2.237882 Grad Norm 1.004885 2.00s/it
# Train loss 13489 2.099157 Grad Norm 0.945010 2.16s/it
# Train loss 13490 2.339106 Grad Norm 1.269826 2.30s/it
# Train loss 13491 2.056171 Grad Norm 1.268028 2.18s/it
# Train loss 13492 2.285925 Grad Norm 1.135056 2.12s/it
# Train loss 13493 2.347609 Grad Norm 1.093555 1.79s/it
# Train loss 13494 2.618331 Grad Norm 1.372852 2.12s/it
# Train loss 13495 2.479413 Grad Norm 1.560787 2.19s/it
# Train loss 13496 1.971976 Grad Norm 0.845301 1.98s/it
# Train loss 13497 2.166286 Grad Norm 1.100845 2.12s/it
# Train loss 13498 2.347293 Grad Norm 1.203054 1.97s/it
# Train loss 13499 2.361113 Grad Norm 1.304400 1.85s/it
# Train loss 13500 2.026652 Grad Norm 1.137176 2.09s/it
# Train loss 13501 2.210333 Grad Norm 1.278241 2.23s/it
# Train loss 13502 2.346553 Grad Norm 1.894414 1.71s/it
# Train loss 13503 2.276061 Grad Norm 1.284682 1.87s/it
# Train loss 13504 2.451736 Grad Norm 1.184222 1.92s/it
# Train loss 13505 2.519187 Grad Norm 1.035534 2.03s/it
# Train loss 13506 2.292768 Grad Norm 1.180814 1.78s/it
# Train loss 13507 1.924265 Grad Norm 1.041207 2.14s/it
# Train loss 13508 2.405246 Grad Norm 1.031508 2.12s/it
# Train loss 13509 2.158183 Grad Norm 1.052810 2.06s/it
# Train loss 13510 2.066753 Grad Norm 1.197638 1.74s/it
# Train loss 13511 1.829833 Grad Norm 1.186269 2.13s/it
# Train loss 13512 2.135499 Grad Norm 1.508282 1.95s/it
# Train loss 13513 2.581582 Grad Norm 1.229687 2.01s/it
# Train loss 13514 2.070300 Grad Norm 1.024076 1.77s/it
# Train loss 13515 2.525912 Grad Norm 1.634652 1.69s/it
# Train loss 13516 1.886508 Grad Norm 1.147630 2.27s/it
# Train loss 13517 2.164500 Grad Norm 1.108063 2.04s/it
# Train loss 13518 2.458575 Grad Norm 1.768350 2.12s/it
# Train loss 13519 1.963780 Grad Norm 1.011542 2.19s/it
# Train loss 13520 2.140606 Grad Norm 0.993552 2.15s/it
# Train loss 13521 1.773172 Grad Norm 0.954353 2.29s/it
# Train loss 13522 2.178979 Grad Norm 0.956526 1.90s/it
# Train loss 13523 1.833244 Grad Norm 1.022330 1.73s/it
# Train loss 13524 2.342487 Grad Norm 1.026130 2.23s/it
# Train loss 13525 2.214724 Grad Norm 1.057255 2.09s/it
# Train loss 13526 2.466707 Grad Norm 1.015527 1.53s/it
# Train loss 13527 2.426821 Grad Norm 0.980622 1.65s/it
# Train loss 13528 2.335070 Grad Norm 0.886808 2.13s/it
# Train loss 13529 2.227177 Grad Norm 1.074490 1.67s/it
# Train loss 13530 2.411465 Grad Norm 1.880304 2.05s/it
# Train loss 13531 2.307676 Grad Norm 0.901124 2.12s/it
# Train loss 13532 2.616610 Grad Norm 1.194315 1.93s/it
# Train loss 13533 2.310123 Grad Norm 0.910494 2.07s/it
# Train loss 13534 2.004441 Grad Norm 0.900927 2.18s/it
# Train loss 13535 1.840173 Grad Norm 1.025821 1.77s/it
# Train loss 13536 2.086216 Grad Norm 1.117260 1.99s/it
# Train loss 13537 1.911833 Grad Norm 1.006996 2.32s/it
# Train loss 13538 2.401876 Grad Norm 0.926188 2.27s/it
# Train loss 13539 2.353505 Grad Norm 0.976287 1.75s/it
# Train loss 13540 2.301178 Grad Norm 1.063667 1.50s/it
# Train loss 13541 2.308254 Grad Norm 1.264448 1.37s/it
# Train loss 13542 2.132672 Grad Norm 0.933864 2.07s/it
# Train loss 13543 1.997930 Grad Norm 0.981108 1.84s/it
# Train loss 13544 2.167387 Grad Norm 1.280900 2.21s/it
# Train loss 13545 2.348053 Grad Norm 1.107585 2.03s/it
# Train loss 13546 2.392107 Grad Norm 1.394212 1.70s/it
# Train loss 13547 2.379251 Grad Norm 0.975184 1.89s/it
# Train loss 13548 1.859707 Grad Norm 0.871210 2.10s/it
# Train loss 13549 2.518871 Grad Norm 1.117910 1.79s/it
# Train loss 13550 2.398871 Grad Norm 0.934465 2.30s/it
# Train loss 13551 1.993264 Grad Norm 0.975892 2.29s/it
# Train loss 13552 2.473491 Grad Norm 1.212381 1.43s/it
# Train loss 13553 2.267311 Grad Norm 0.910717 2.26s/it
# Train loss 13554 2.265624 Grad Norm 1.107708 2.07s/it
# Train loss 13555 2.397639 Grad Norm 1.012903 2.16s/it
# Train loss 13556 2.252748 Grad Norm 1.063259 1.87s/it
# Train loss 13557 2.504096 Grad Norm 1.404613 2.08s/it
# Train loss 13558 2.166054 Grad Norm 1.216648 2.09s/it
# Train loss 13559 2.566168 Grad Norm 1.111554 2.00s/it
# Train loss 13560 2.649149 Grad Norm 1.198636 1.92s/it
# Train loss 13561 2.607249 Grad Norm 1.363475 1.27s/it
# Train loss 13562 2.282440 Grad Norm 1.018788 2.05s/it
# Train loss 13563 2.035437 Grad Norm 1.072859 2.18s/it
# Train loss 13564 2.045469 Grad Norm 0.945455 2.23s/it
# Train loss 13565 2.664225 Grad Norm 1.204701 1.76s/it
# Train loss 13566 2.382725 Grad Norm 1.212343 2.21s/it
# Train loss 13567 2.530084 Grad Norm 1.151132 1.92s/it
# Train loss 13568 2.454978 Grad Norm 1.089009 1.81s/it
# Train loss 13569 2.150906 Grad Norm 1.140390 1.53s/it
# Train loss 13570 1.994780 Grad Norm 0.894245 2.26s/it
# Train loss 13571 1.977803 Grad Norm 1.040612 2.06s/it
# Train loss 13572 1.901404 Grad Norm 0.902896 2.22s/it
# Train loss 13573 1.976321 Grad Norm 1.108114 1.83s/it
# Train loss 13574 2.136984 Grad Norm 1.178102 2.18s/it
# Train loss 13575 2.115766 Grad Norm 1.141932 2.19s/it
# Train loss 13576 2.242766 Grad Norm 1.102768 1.74s/it
# Train loss 13577 2.417413 Grad Norm 1.134675 1.92s/it
# Train loss 13578 1.836581 Grad Norm 0.913808 1.66s/it
# Train loss 13579 1.781444 Grad Norm 0.804926 1.78s/it
# Train loss 13580 2.355635 Grad Norm 1.144734 1.34s/it
# Train loss 13581 2.255058 Grad Norm 1.072531 2.03s/it
# Train loss 13582 1.956033 Grad Norm 1.054207 1.69s/it
# Train loss 13583 2.447255 Grad Norm 1.103181 1.94s/it
# Train loss 13584 2.231033 Grad Norm 0.996067 1.94s/it
# Train loss 13585 1.350269 Grad Norm 0.730110 2.11s/it
# Train loss 13586 1.535291 Grad Norm 1.182017 2.11s/it
# Train loss 13587 2.692300 Grad Norm 1.220071 2.06s/it
# Train loss 13588 2.198073 Grad Norm 0.937652 2.48s/it
# Train loss 13589 2.610778 Grad Norm 1.476898 2.41s/it
# Train loss 13590 2.453500 Grad Norm 1.096143 1.82s/it
# Train loss 13591 2.380641 Grad Norm 1.194482 2.14s/it
# Train loss 13592 2.033610 Grad Norm 1.047446 1.98s/it
# Train loss 13593 1.810874 Grad Norm 0.917584 2.03s/it
# Train loss 13594 2.627353 Grad Norm 1.138083 2.24s/it
# Train loss 13595 2.418513 Grad Norm 1.055761 1.71s/it
# Train loss 13596 2.198524 Grad Norm 1.026309 2.09s/it
# Train loss 13597 2.433613 Grad Norm 1.044059 1.74s/it
# Train loss 13598 2.237344 Grad Norm 0.920949 2.17s/it
# Train loss 13599 2.593472 Grad Norm 0.956770 2.23s/it
# Train loss 13600 1.864047 Grad Norm 0.925403 1.71s/it
# Train loss 13601 1.821698 Grad Norm 1.049814 2.09s/it
# Train loss 13602 2.108007 Grad Norm 1.238045 1.95s/it
# Train loss 13603 2.375360 Grad Norm 1.129091 1.89s/it
# Train loss 13604 2.048444 Grad Norm 1.085458 2.03s/it
# Train loss 13605 2.331011 Grad Norm 1.256715 2.09s/it
# Train loss 13606 1.995797 Grad Norm 0.960282 1.80s/it
# Train loss 13607 2.368556 Grad Norm 1.156225 2.05s/it
# Train loss 13608 2.508201 Grad Norm 1.448244 1.85s/it
# Train loss 13609 2.056230 Grad Norm 1.208801 1.77s/it
# Train loss 13610 2.542174 Grad Norm 1.348826 1.40s/it
# Train loss 13611 1.738640 Grad Norm 0.813556 2.16s/it
# Train loss 13612 2.196784 Grad Norm 1.049395 1.94s/it
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e8dfbe74aede> in <module>()
#      10     loss = criterion(y_pred, y)
#      11     reduced_loss = loss.item()  #[1.0] -> 1.0
# ---> 12     loss.backward()
#      13     grad_norm = torch.nn.utils.clip_grad_norm_(
#      14         model.parameters(), hparams.grad_clip_thresh)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %% [markdown]
# ### Reference

# %% [markdown]
# - https://www.youtube.com/watch?v=Li_L-B-ob3k&t=1333s
# - [토크ON세미나] 딥러닝 기반 음성합성
